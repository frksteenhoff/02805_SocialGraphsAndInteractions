# %% [markdown]
# # Week 4
# ## Notes

# %% [markdown]
# ### Regular Expressions in Python
# More about [regular expressions](https://developers.google.com/edu/python/regular-expressions)

# %%
import re # import regular expression module

# %%
# Basic
str = 'an example word:cat!!'
match = re.search(r'word:\w\w\w', str)
# If-statement after search() tests if it succeeded
if match:                      
  print 'found', match.group()
else:
  print 'did not find'
# Out:
# found word:cat

# %% [markdown]
# #### Findall

# %%
## Suppose we have a text with many email addresses
  str = 'purple alice@google.com, blah monkey bob@abc.com blah dishwasher'

  ## Here re.findall() returns a list of all the found email strings
  emails = re.findall(r'[\w\.-]+@[\w\.-]+', str) ## ['alice@google.com', 'bob@abc.com']
  for email in emails:
    # do something with each found email string
    print email

# %% [markdown]
# ## Exercises

# %% [markdown]
# **What are regular expressions?**
#
# Regular expressions uses pattern matching to find customized strings, substrings, repetitions etc. in texts and other material. There are many different ways to specify what you want.
#
# It is a sequence of characters that define a search pattern, mainly for use in pattern matching with strings, or string matching. It is the same as what is used when finding and replacing in Word etc.

# %% [markdown]
# **Regex to match 4 digit number**
#
# [Place to test regular expressions](https://regex101.com/)
#
# **An even better place to [test regex'es](https://regexr.com/)**

# %%
# Match exatcly 4 digits, no more no less.
# \d = digit char, \w = word char
# ''r' indicates a 'raw' string

# Fetching test content (for all examples here)
import urllib2
response = urllib2.urlopen('https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt')
html = response.read()

str = "hello54o oo  5688oo 63855"
# Matches 4 digits, possibly separated by whitespace
# Using lookbehind and lookahead
match = re.findall(r'(?<!\d)[0-9]{4}(?!\d)', html)
# match = re.search(r'^[0-9]{4}', str) 

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['1234', '9999']

# %% [markdown]
# **Provide an example of a regex to match words starting with "super".**
#
# Show that it works on the [test-text](https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt).

# %%
# Regex matching words STARTING with super
match = re.findall(r'super\w+', html)

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['superpolaroid', 'supertaxidermy', 'superbeer']

# %% [markdown]
# ### Regular expression pt. 2
# Getting the Wiki-links

# %%
# Show that you can extract the wiki-links from the test-text. 
match = re.findall(r'\[\[(?:[^|\]]*\|)?([^\]]+)\]\]', html)

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['drinking vinegar', 'gentrify', 'hashtag', 'Bicycle(two-wheeled type)', 'Pitchfork Magazine']

# %% [markdown]
# ## A Fun with Wikipedia

# %% [markdown]
# How to get the pages/markup through the Wiki-API
#
# ### Basic Statistics - philosopher's

# %%
import urllib2
import re
import json
response = urllib2.urlopen('https://en.wikipedia.org/wiki/List_of_aestheticians')
html = response.read()

# %%
# Getting the philosopher informatiom
baseurl    = "https://en.wikipedia.org/w/api.php?"
action     = "action=query"
title      = "titles="
content    = "prop=revisions&rvprop=content"
dataformat = "format=json"

# List of all Philosophers by core area
list_phil = ['List_of_aestheticians','List_of_epistemologists','List_of_ethicists','List_of_logicians','List_of_metaphysicians','List_of_social_and_political_philosophers']
query = []
phil_count = 0
all_phil = []

# constructing query for getting all Philosopher data
for core_area in list_phil:
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+core_area,content,dataformat)

    f = urllib2.urlopen(query)
    area_links = re.findall(r'\*.?\[\[([^\]|]+)\|?[^\]]*\]\]',f.read())
    trim_area_links = [item for item in area_links if not item.lower().startswith('list of')]
    all_phil.append(trim_area_links)
    print "Query for:", core_area
    print (query)
    print "Number of philosophers: ", len(trim_area_links)
    print
    #print trim_area_links
    
    # Accumulate number of philosophers
    phil_count = phil_count + len(trim_area_links)

print "Philosophers in all: ", phil_count # each core area not accouting for duplicates
# Out:
# Query for: List_of_aestheticians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_aestheticians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  124
#
# Query for: List_of_epistemologists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_epistemologists&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  98
#
# Query for: List_of_ethicists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_ethicists&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  272
#
# Query for: List_of_logicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_logicians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  271
#
# Query for: List_of_metaphysicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_metaphysicians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  96
#
# Query for: List_of_social_and_political_philosophers
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_social_and_political_philosophers&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  294
#
# Philosophers in all:  1155
# [['Andreas Linder', 'Virgil Aldrich', 'Anandavardhana', 'Sri Aurobindo', 'John Anderson (philosopher)', 'Yves Marie Andr\xc3\xa9', 'Aristotle', 'Rudolf Arnheim', 'Mazen Asfour', 'Georg Anton Friedrich Ast', 'Jody Azzouni', 'Victor Basch', 'Yusuf Balasagun', 'Roland Barthes', 'Georges Bataille', 'Alexander Gottlieb Baumgarten', 'Monroe Beardsley', 'Vissarion Belinsky', 'Clive Bell', 'Walter Benjamin', 'Arnold Berleant', 'George Birkhoff', 'Max Black', 'Maurice Blanchot', 'Harold Bloom', 'Georg Brandes', 'Cameron Breen', 'Jean Anthelme Brillat-Savarin', 'Ferruccio Busoni', 'John Cage', 'Cesare Brandi', 'Stanley Cavell', 'R. G. Collingwood', 'Victor Cousin', 'Benedetto Croce', 'Gregory Currie', 'Arthur Danto', 'William C. Dowling', 'John Dewey', 'Umberto Eco', 'Jonathan Edwards (theologian)', 'Ralph Waldo Emerson', 'Jerry Farber', 'Valentin Feldman', 'Henri Focillon', 'Michel Foucault', 'Hans-Georg Gadamer', 'Alexander Gerard', 'Nelson Goodman', 'Edmund Gurney', 'Etienne Gilson', 'Paul H\xc3\xa4berlin', 'Garry Hagberg', 'Ferdinand Gotthelf Hand', 'Eduard Hanslick', 'Georg Wilhelm Friedrich Hegel', 'Fran\xc3\xa7ois Hemsterhuis', 'Johann Friedrich Herbart', 'Johann Gottfried Herder', 'Hermann Theodor Hettner', 'John Hospers', 'Heinrich Gustav Hotho', 'David Hume', 'Francis Hutcheson (philosopher)', 'Francis Ernest Jackson', 'Christopher Janaway', 'James Joyce', 'Immanuel Kant', 'Mani Kaul', 'S\xc3\xb8ren Kierkegaard', 'Peter Kivy', 'Andrzej Tadeusz Kijowski', 'Joseph Kosuth', 'Susanne Langer', 'Vernon Lee', 'Gotthold Ephraim Lessing', 'Jerrold Levinson', 'Liu Xie', 'Longinus (literature)', 'Peter Lunenfeld', 'Jean-Fran\xc3\xa7ois Lyotard', 'Gy\xc3\xb6rgy Luk\xc3\xa1cs', 'John Maeda', 'Andr\xc3\xa9 Malraux', 'Jacques Maritain', 'Georg Mehlis', 'Richard Meltzer', 'Theodor Mundt', 'Sam Murgatroyd', 'Friedrich Nietzsche', 'Michael Oakeshott', 'Lalita Pandit', 'Walter Pater', 'Ronald Paulson', 'Hans Pfitzner', 'Plato', 'Edgar Allan Poe', 'Steven Poole', 'Ayn Rand', 'Thomas Reid', 'John Ruskin', 'George Santayana', 'Friedrich Wilhelm Joseph von Schelling', 'Friedrich Schiller', 'August Wilhelm Schlegel', 'Karl Wilhelm Friedrich von Schlegel', 'Arthur Schopenhauer', 'Roger Scruton', 'Calvin Seerveld', 'Richard Shusterman', 'Frank Sibley (philosopher)', 'Eli Siegel', 'Guy Sircello', 'Karl Wilhelm Ferdinand Solger', 'Michael Sprinker', 'Algernon Charles Swinburne', 'Socrates', 'Luca Vercelloni', 'Tudor Vianu', 'Kendall Walton', 'Morris Weitz', 'Oscar Wilde', 'W.K. Wimsatt', 'Richard Wollheim'], ['William Alston', 'Aristotle', 'Robert Audi', 'A. J. Ayer', 'Francis Bacon', 'George Berkeley', 'Harry Binswanger', 'David Bohm', 'Laurence Bonjour', 'Berit Brogaard', 'Mario Bunge', 'Judith Butler', 'David Chalmers', 'Noam Chomsky', 'Jonathan Dancy', 'Simone de Beauvoir', 'Ren\xc3\xa9 Descartes', 'Fred Dretske', 'Nader El-Bizri', 'Margaret Elizabeth Egan', 'Catherine Elgin', 'Heinz von Foerster', 'Edmund Gettier', 'Ernst von Glasersfeld', 'Alvin Goldman', 'Emma Goldman', 'Nelson Goodman', 'John_Greco (philosopher)', 'Paul Grice', 'Susan Haack', 'Donna Haraway', 'Sandra Harding', 'Gilbert Harman', 'Sally Haslanger', 'Friedrich A. Hayek', 'G.W.F. Hegel', 'John Hawthorne', 'Thomas Hobbes', 'David Hume', 'James VI and I', 'Carrie Ichikawa Jenkins', 'Immanuel Kant', 'S\xc3\xb8ren Kierkegaard', 'Peter D. Klein', 'Hilary Kornblith', 'Jennifer Lackey', 'Keith Lehrer', 'Isaac Levi', 'David Lewis (philosopher)', 'Peter Lipton', 'John Locke', 'Niklas Luhmann', 'Norman Malcolm', 'Terence McKenna', 'Trenton Merricks', 'Ludwig von Mises', 'Jean-Louis Le Moigne', 'George Edward Moore', 'Edgar Morin', 'Mioara Mugur-Sch\xc3\xa4chter', 'Robert Nozick', 'William of Ockham', 'George Pappas', 'L.A. Paul', 'Leonard Peikoff', 'Jean Piaget', 'Tomek Pietkiewicz', 'Gualtiero Piccinini', 'Alvin Plantinga', 'Plato', 'Louis Pojman', 'Karl Popper', 'W.V.O. Quine', 'Ayn Rand', 'Sherrilyn Roush', 'Bertrand Russell', 'John Searle', 'Susanna Schellenberg', 'Susanna Siegel', 'Socrat ...

# %% [markdown]
# **Which is the largest branch of philosophy?**
#
# Judging by the number of philosophers in the different groups, the philosophers within social and political philosophy is the greatest branch. They are closely followed by Logicians and Ethicists.

# %% [markdown]
# **Philosophers in several lists?**
#
# To solve this problem it is easiest to use the list of all philosophers. To see whether they are in several lists, one need to look at the list with all names, where none has been removed to avoid duplication.

# %%
from collections import Counter
in_several_lists = Counter(brac)
#print in_several_lists
print "Philosopher in most lists: "
print in_several_lists.most_common(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b5d39be2fd5c> in <module>()
#       1 from collections import Counter
# ----> 2 in_several_lists = Counter(all_phil)
#       3 #print in_several_lists
#       4 print "Philosopher in most lists: "
#       5 print in_several_lists.most_common(1)
#
# C:\Users\frksteenhoff\Anaconda2\lib\collections.pyc in __init__(*args, **kwds)
#     475             raise TypeError('expected at most 1 arguments, got %d' % len(args))
#     476         super(Counter, self).__init__()
# --> 477         self.update(*args, **kwds)
#     478
#     479     def __missing__(self, key):
#
# C:\Users\frksteenhoff\Anaconda2\lib\collections.pyc in update(*args, **kwds)
#     565                 self_get = self.get
#     566                 for elem in iterable:
# --> 567                     self[elem] = self_get(elem, 0) + 1
#     568         if kwds:
#     569             self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# **List of philosophers in more than one list**

# %%
import operator

popular_phil = {}
temp = dict(Counter(in_several_lists))

# Getting the values of philosophers in lists > 1
for key, value in temp.iteritems():
    if value > 1:
        popular_phil[key] = value

sorted_phil = sorted(popular_phil.items(), key=lambda x: (-x[1], x[0]))
print sorted_phil
# Out:
# [(u'Aristotle', 6), (u'Bertrand Russell', 5), (u'Immanuel Kant', 5), (u'Plato', 5), (u'Ayn Rand', 4), (u'Arthur Schopenhauer', 3), (u'David Hume', 3), (u'Georg Wilhelm Friedrich Hegel', 3), (u'Gottfried Leibniz', 3), (u'John Locke', 3), (u'John Stuart Mill', 3), (u'Judith Butler', 3), (u'Ludwig Wittgenstein', 3), (u'Mario Bunge', 3), (u'Nelson Goodman', 3), (u'Ruth Barcan Marcus', 3), (u'Susan Haack', 3), (u'S\xf8ren Kierkegaard', 3), (u'Thomas Aquinas', 3), (u'Abraham Joshua Heschel', 2), (u'Alain Badiou', 2), (u'Alfred North Whitehead', 2), (u'Alvin Plantinga', 2), (u'B. R. Ambedkar', 2), (u'Baruch Spinoza', 2), (u'Berit Brogaard', 2), (u'Catherine Elgin', 2), (u'Christian Wolff (philosopher)', 2), (u'Confucius', 2), (u'Constantin R\u0103dulescu-Motru', 2), (u'David Chalmers', 2), (u'David Kolb', 2), (u'Edward Said', 2), (u'Emma Goldman', 2), (u'Francis Bacon', 2), (u'Francis Hutcheson (philosopher)', 2), (u'Friedrich Nietzsche', 2), (u'Friedrich Schiller', 2), (u'G. E. Moore', 2), (u'George Berkeley', 2), (u'George Boole', 2), (u'Georges Bataille', 2), (u'Giambattista Vico', 2), (u'Gilbert Harman', 2), (u'Gottlob Frege', 2), (u'Graham Priest', 2), (u'Gualtiero Piccinini', 2), (u'Henry Sidgwick', 2), (u'Herbert Spencer', 2), (u'Hilary Putnam', 2), (u'Hugo Grotius', 2), (u'J. J. C. Smart', 2), (u'Jean-Fran\xe7ois Lyotard', 2), (u'Jean-Jacques Rousseau', 2), (u'Jeremy Bentham', 2), (u'Jessica Wilson', 2), (u'John Finnis', 2), (u'John Hawthorne', 2), (u'John Hospers', 2), (u'John Rawls', 2), (u'John Ruskin', 2), (u'John Searle', 2), (u'Joseph Raz', 2), (u'Joxe Azurmendi', 2), (u'Judith Jarvis Thomson', 2), (u'J\xfcrgen Habermas', 2), (u'Karl Popper', 2), (u'Karl Wilhelm Friedrich von Schlegel', 2), (u'Karl-Otto Apel', 2), (u'Kit Fine', 2), (u'L.A. Paul', 2), (u'Lorenzo Pe\xf1a', 2), (u'Ludwig von Mises', 2), (u'Mao Zedong', 2), (u'Martha Nussbaum', 2), (u'Martin Heidegger', 2), (u'Martin Luther King, Jr.', 2), (u'Maurice Blanchot', 2), (u'Max Stirner', 2), (u'Mencius', 2), (u'Michael Oakeshott', 2), (u'Michel Foucault', 2), (u'Michel Onfray', 2), (u'Mortimer Adler', 2), (u'Mozi', 2), (u'Murray Bookchin', 2), (u'Murray Rothbard', 2), (u'Nader El-Bizri', 2), (u'Niccol\xf2 Machiavelli', 2), (u'Noam Chomsky', 2), (u'P. F. Strawson', 2), (u'Paul Benacerraf', 2), (u'Paul of Venice', 2), (u'Penelope Maddy', 2), (u'Peter Geach', 2), (u'Peter Kropotkin', 2), (u'Peter Unger', 2), (u'Peter of Spain (author)', 2), (u'Philip Pettit', 2), (u'Ren\xe9 Descartes', 2), (u'Robert Nozick', 2), (u'Robert S. Hartman', 2), (u'Ronald Dworkin', 2), (u'Sally Haslanger', 2), (u'Saul Kripke', 2), (u'Socrates', 2), (u'Sun Yat-sen', 2), (u'T. M. Scanlon', 2), (u'Thomas Hill Green', 2), (u'Thomas Hobbes', 2), (u'Thomas Nagel', 2), (u'Trenton Merricks', 2), (u'Walter Benjamin', 2), (u'Walter Terence Stace', 2), (u'William Alston', 2), (u'William of Ockham', 2)]

# %% [markdown]
# **'Top 5 guys'**

# %%
print in_several_lists.most_common(5)
# Out:
# [(u'Aristotle', 7), (u'Plato', 6), (u'Bertrand Russell', 6), (u'Immanuel Kant', 6), (u'Ayn Rand', 5)]

# %% [markdown]
# Yes, I know Aristotle, Plato, Russell and Kant.

# %% [markdown]
# ### Creating the Philosopher's network

# %%
# Work on all collected data (saved in one file)
import io
import re
import numpy as np

f = io.open('./markup.txt','r',encoding='utf-8')
brac = re.findall(r'\*\s*\[\[([^\]|]+)\|?[^\]]*\]\]', f.read())

# %%
#Getting only unique values
unique_brac = np.unique(brac)

# Remove unwanted links 
trim_phil = [item for item in unique_brac if not item.lower().startswith('list of')]

# Printing the values
for link in trim_phil:
    print link
# Out:
# :nl:Martinus Dorpius
# A. J. Ayer
# Abraham Fraenkel
# Abraham Joshua Heschel
# Abraham Robinson
# Abraham ibn Daud
# Abul Kalam Azad
# Adam Müller
# Adam Smith
# Adolf Lindenbaum
# Adrian Johnston (philosopher)
# Ahmed Raza Khan
# Alain Badiou
# Alan Bundy
# Alan Carter (philosopher)
# Alan Gewirth
# Alan Ross Anderson
# Alan Ryan
# Alan Turing
# Alasdair MacIntyre
# Alasdair Urquhart
# Alastair Norcross
# Albert Camus
# Albert Schweitzer
# Albert of Saxony (philosopher)
# Alcuin
# Aldo Leopold
# Alexander Bain
# Alexander Campbell Fraser
# Alexander Esenin-Volpin
# Alexander Gerard
# Alexander Gottlieb Baumgarten
# Alexander S. Kechris
# Alexander Zinoviev
# Alexis de Tocqueville
# Alfred Horn
# Alfred North Whitehead
# Alfred Rosenberg
# Alfred Tarski
# Algernon Charles Swinburne
# Ali Shariati
# Alice Crary
# Alija Izetbegović
# Allan Gibbard
# Alon Ben-Meir
# Alonzo Church
# Alvin Goldman
# Alvin Plantinga
# Amartya Sen
# Ambrose
# Anandavardhana
# Anaximander
# Andrea Bonomì
# Andreas Linder
# Andrei Marga
# Andronicus of Rhodes
# Andrzej Mostowski
# Andrzej Tadeusz Kijowski
# André Malraux
# Anne Conway (philosopher)
# Anne Sjerp Troelstra
# Anthony de Jasay
# Antoine Garaby de La Luzerne
# Antonio Negri
# António Castanheira Neves
# Archon
# Arda Denkel
# Arend Heyting
# Aristotle
# Aristoxenus
# Armin Mohler
# Arnold Berleant
# Arthur Caplan
# Arthur Danto
# Arthur Linton Corbin
# Arthur Moeller van den Bruck
# Arthur Prior
# Arthur Schopenhauer
# Ashoka
# Auberon Herbert
# August Wilhelm Schlegel
# Augustine of Hippo
# Augustus De Morgan
# Austin Osman Spare
# Averroes
# Avicenna
# Axel Honneth
# Ayn Rand
# B. F. Skinner
# B. R. Ambedkar
# Bahmanyār
# Bahya ibn Paquda
# Bahá'u'lláh
# Barron H. Lerner
# Barry Stroud
# Baruch Spinoza
# Benedetto Croce
# Benjamin Tucker
# Benjamin Wiker
# Berit Brogaard
# Bernard Bolzano
# Bernard Williams
# Bertrand Russell
# Bertrand de Jouvenel
# Bjarni Jónsson
# Blaise Pascal
# Bob Meyer (logician)
# Boethius
# Boris Furlan
# Brian Leftow
# Bruce Lee
# Bruno Leoni
# Bryan Caplan
# C. D. Broad
# Calvin Seerveld
# Cameron Breen
# Carew Arthur Meredith
# Carl Joachim Friedrich
# Carl Schmitt
# Carlo Lottieri
# Carlos Santiago Nino
# Carol Gilligan
# Carrie Ichikawa Jenkins
# Carveth Read
# Catherine Elgin
# Cesare Brandi
# Chanakya
# Charles Blattberg
# Charles Parsons (philosopher)
# Charles Sanders Peirce
# Charles Stevenson
# Charles Taylor (philosopher)
# Chaïm Perelman
# Cheng Hao
# Cheng Yi (philosopher)
# Christian Wolff (philosopher)
# Christine Korsgaard
# Christine Ladd-Franklin
# Christopher Janaway
# Chrysippus
# Clarence Irving Lewis
# Claude Adrien Helvétius
# Claude Lefort
# Claude Lévi-Strauss
# Claudio Canaparo
# Clive Bell
# Colin Wilson
# Confucius
# Conimbricenses
# Constantin Rădulescu-Motru
# Cora Diamond
# Cornel West
# Cornelius Castoriadis
# Costas Douzinas
# Craig Paterson
# Dag Prawitz
# Damon Young
# Dana Scott
# Dana Ward
# Daniel Brock
# Daniel Guérin
# Daniel Wikler
# David Bohm
# David Chalmers
# David Crocker
# David D. Friedman
# David Friedrich Strauss
# David Gauthier
# David Hilbert
# David Hume
# David K. Lewis
# David Kaplan (philosopher)
# David Kellogg Lewis
# David Kolb
# David Korten
# David L. Norton
# David Lewis (philosopher)
# David Makinson
# David Malet Armstrong
# David Miller (political theorist)
# David Pearce (philosopher)
# David Prychitko
# David Schmidtz
# David Sosa
# David Wiggins
# Dean Zimmerman
# Democritus
# Derek Parfit
# Dharmakirti
# Dick de Jongh
# Dietrich Bonhoeffer
# Dignāga
# Dimiter Skordev
# Dimitris Dimitrakos
# Diodorus Cronus
# Dirk van Dalen
# Disciples of Confucius
# Donald A. Martin
# Donella Meadows
# Dong Zhongshu
# Donna Haraway
# Dov Gabbay
# Dugald Macpherson
# Dugald Stewart
# Duncan Kennedy (legal philosopher)
# Duns Scotus
# Edgar Allan Poe
# Edgar Morin
# Edmund Gettier
# Edmund Gurney
# Eduard Hanslick
# Edward Hundert
# Edward Nelson
# Edward Said
# Ehud Hrushovski
# Eli Siegel
# Elizabeth Harman (disambiguation)
# Elliot N. Dorff
# Emil Leon Post
# Emma Goldman
# Emma Rush
# Emmanuel Levinas
# Enrique Dussel
# Epicurus
# Eric Voegelin
# Erich Fromm
# Erich Heller
# Ernest Sosa
# Ernest Wamba dia Wamba
# Ernst Bloch
# Ernst Schröder
# Ernst Zermelo
# Ernst von Glasersfeld
# Etienne Gilson
# Eugen Rosenstock-Huessy
# Evert Willem Beth
# Fatema Mernissi
# Fazlur Rahman
# Felix Kaufmann
# Ferdinand Gotthelf Hand
# Ferruccio Busoni
# Francesco D'Andrea
# Francis Bacon
# Francis Ernest Jackson
# Francis Fukuyama
# Francis Hutcheson (philosopher)
# Francis Jeffrey
# Francis Parker Yockey
# Francisco de Vitoria
# Franco Burgersdijk
# Frank Herbert
# Frank Meyer (political philosopher)
# Frank Plumpton Ramsey
# Frank Schmalleger
# Frank Sibley (philosopher)
# Franz Xaver von Baader
# François Hemsterhuis
# Fred Dretske
# Fred Poché
# Frederick Rowbottom
# Friedrich A. Hayek
# Friedrich Adolf Trendelenburg
# Friedrich Daniel Ernst Schleiermacher
# Friedrich Eduard Beneke
# Friedrich Hayek
# Friedrich Nietzsche
# Friedrich Schiller
# Friedrich Wilhelm Joseph von Schelling
# Frithjof Schuon
# Fujiwara Seika
# Fyodor Shcherbatskoy
# Félix Guattari
# G. E. M. Anscombe
# G. E. Moore
# G.W.F. Hegel
# Gabriele Taylor
# Gaisi Takeuti
# Galileo Galilei
# Garlandus Compotista
# Garry Hagberg
# Gary Chartier
# Gary R. Mar
# Gautama Buddha
# Gene Callahan (economist)
# Geoffrey Sayre-McCord
# Georg Anton Friedrich Ast
# Georg Brandes
# Georg Cantor
# Georg Henrik von Wright
# Georg Jellinek
# Georg Kreisel
# Georg Mehlis
# Georg Simmel
# Georg W. F. Hegel
# Georg Wilhelm Friedrich Hegel
# George Berkeley
# George Birkhoff
# George Boole
# George Boolos
# George Croom Robertson
# George Edward Moore
# George Holmes Howison
# George Kateb
# George Ohsawa
# George Pappas
# George Santayana
# Georges Bataille
# Gerald Cohen
# Gerald Dworkin
# Gerald Sacks
# Gerhard Gentzen
# Gerhard Vollmer
# Gerrard Winstanley
# Ghazali
# Giacomo Marramao
# Giambattista Vico
# Gianfranco Sanguinetti
# Giannina Braschi
# Gilbert Harman
# Gilbert Simondon
# Gilbert de la Porrée
# Gilles Deleuze
# Giorgi Japaridze
# Giorgio Agamben
# Giorgio Del Vecchio
# Giovanni Battista Scaramelli
# Giovanni Girolamo Saccheri
# Giuseppe Peano
# Glenn McGee
# Gottfried Leibniz
# Gotthold Ephraim Lessing
# Gottlob Frege
# Graeme Forbes
# Graham Priest
# Gregory Chaitin
# Gregory Currie
# Grigori Mints
# Gualtiero Piccinini
# Gustave de Molinari
# Guy Aldred
# Guy Debord
# Guy Sircello
# György Lukács
# H. B. Acton
# H. L. A. Hart
# H. Richard Niebuhr
# Hammurabi
# Han Fei
# Han Ryner
# Hannah Arendt
# Hans Achterhuis
# Hans Kelsen
# Hans Köchler
# Hans Küng
# Hans Pfitzner
# Hans-Georg Gadamer
# Hans-Hermann Hoppe
# Hao Wang (academic)
# Har Dayal
# Harold Bloom
# Harriet Taylor Mill
# Harry Binswanger
# Hartry Field
# Harvey Friedman
# Haskell Curry
# Hayashi Razan
# Heinrich Gustav Hotho
# Heinz von Foerster
# Heiric of Auxerre
# Helena Rasiowa
# Henk Barendregt
# Henri Bergson
# Henri Focillon
# Henri Lefebvre
# Henry Babcock Veatch
# Henry David Thoreau
# Henry George
# Henry Hazlitt
# Henry Home, Lord Kames
# Henry Pachter
# Henry Sidgwick
# Heraclitus
# Herbert Spencer
# Herman Oliphant
# Hermann Lotze
# Hermann Theodor Hettner
# Hierocles of Alexandria
# Hilary Kornblith
# Hilary Putnam
# Hirata Atsutane
# Holly Martin Smith
# Horace Romano Harré
# Houston Stewart Chamberlain
# Howard Zinn
# Hsun Tzu
# Hugh MacColl
# Hugo Grotius
# Hui Shi
# Ian Rumfitt
# Ibn Taymiyyah
# Igor Pribac
# Immanuel Kant
# Inayatullah Khan Mashriqi
# Iris Marion Young
# Isaac Levi
# Isaac Malitz
# Isaac Watts
# Isabel Paterson
# Isaiah Berlin
# Ismail Raji' al-Faruqi
# Israel Kirzner
# Israr Ahmed
# Itō Jinsai
# Ivan Orlov (philosopher)
# Ivan Sviták
# J. Barkley Rosser
# J. J. C. Smart
# J. L. Mackie
# J. M. E. McTaggart
# Jaakko Hintikka
# Jack Copeland
# Jack Russell Weinstein
# Jacob M. Appel
# Jacopo Zabarella
# Jacques Herbrand
# Jacques Maritain
# Jacques Rancière
# James Brusseau
# James Childress
# James Earl Baumgartner
# James Frederick Ferrier
# James Hinton
# James Joyce
# James Martineau
# James Mill
# James Tully (philosopher)
# James VI and I
# Jamie Whyte
# Jan Łukasiewicz
# Jane Jacobs
# Janet Biehl
# Janet Coleman
# Jaoudat Khouri
# Jawaharlal Nehru
# Jay Rosenberg
# Jean Anthelme Brillat-Savarin
# Jean Bodin
# Jean Buridan
# Jean Grondin
# Jean Nicod
# Jean Piaget
# Jean Van Heijenoort
# Jean-François Lyotard
# Jean-Jacques Rousseau
# Jean-Louis Le Moigne
# Jean-Paul Sartre
# Jean-Yves Béziau
# Jean-Yves Girard
# Jeff Paris
# Jeffrey Friedman (political scientist)
# Jeffrey Stout
# Jennifer Lackey
# Jenny Teichman
# Jeremy Bentham
# Jeroen Groenendijk
# Jerrold Levinson
# Jerry Farber
# Jerzy Łoś
# Jessica Wilson
# Jesus
# Jin Yuelin
# Joachim Jungius
# Joachim Lambek
# Joan Tronto
# Jody Azzouni
# Johan van Benthem (logician)
# Johann Albert Fabricius
# Johann Friedrich Herbart
# Johann Georg Walch
# Johann Gottfried Herder
# Johann Heinrich Lambert
# John Anderson (philosopher)
# John Arthur (philosopher)
# John Austin (legal philosopher)
# John Burnheim
# John Cage
# John Corcoran (logician)
# John Dewey
# John Dumbleton
# John Duns Scotus
# John Etchemendy
# John Finnis
# John Harsanyi
# John Hawthorne
# John Hospers
# John Howard Yoder
# John Joseph O'Connor
# John Lane Bell
# John Locke
# John M. Cooper
# John Maeda
# John Major (philosopher)
# John McDowell
# John Oswald (activist)
# John Pagus
# John Peters Humphrey
# John R. Steel
# John Ralston Saul
# John Rawls
# John Ruskin
# John Searle
# John Shelby Spong
# John Stevens Cabot Abbott
# John Stuart Mill
# John Venn
# John William Miller
# John Woods (logician)
# John Zerzan
# John of St. Thomas
# John von Neumann
# John_Greco (philosopher)
# Jon Barwise
# Jonathan Dancy
# Jonathan Edwards (theologian)
# Jonathan Wolff (philosopher)
# Joseph Diaz Gergonne
# Joseph Fins
# Joseph Fletcher
# Joseph Kosuth
# Joseph Priestley
# Joseph Priestley and Dissent
# Joseph Raz
# Joseph de Torre
# Joshua Cohen (philosopher)
# Joxe Azurmendi
# Juan Luis Vives
# Judith Butler
# Judith Jarvis Thomson
# Jules Vuillemin
# Julia Annas
# Julia Driver
# Julian Gumperz
# Julian Savulescu
# Julien Offray de La Mettrie
# Julius Binder
# Józef Maria Bocheński
# Jürgen Habermas
# Kaibara Ekken
# Karel Lambert
# Karl Immanuel Nitzsch
# Karl Loewenstein
# Karl Marx
# Karl Popper
# Karl Wilhelm Ferdinand Solger
# Karl Wilhelm Friedrich von Schlegel
# Karl-Otto Apel
# Karla Jessen Williamson
# Kazimierz Ajdukiewicz
# Kazimierz Twardowski
# Keith Lehrer
# Kendall Walton
# Kevin Carson
# Kit Fine
# Kurt Gödel
# Kurt Schütte
# L. T. F. Gamut
# L.A. Paul
# Lalita Pandit
# Langdon Winner
# Laurence Bonjour
# Lauri Ingman
# Lawrence Kohlberg
# Lennart Åqvist
# Leo Harrington
# Leo Tolstoy
# Leon Chwistek
# Leon Henkin
# Leonard Borgzinner
# Leonard Peikoff
# Leonard Read
# Leonidas Donskis
# Leopold Kronecker
# Leopold Löwenheim
# Leslie Stephen
# Lewis Call
# Lewis Carroll
# Linda Trinkaus Zagzebski
# Liu Xie
# Lon L. Fuller
# Longinus (literature)
# Loren Lomasky
# Lorenzo Peña
# Lorenzo Valla
# Lotfi A. Zadeh
# Louis Althusser
# Louis Pojman
# Luca Vercelloni
# Lucius Annaeus Seneca
# Lucretius
# Ludwig Wittgenstein
# Ludwig von Mises
# Luitzen Egbertus Jan Brouwer
# Lynne Rudder Baker
# Lysander Spooner
# Maimonides
# Mani Kaul
# Manuel De Landa
# Mao Zedong
# Marcion of Sinope
# Margaret Canovan
# Margaret Elizabeth Egan
# Margaret Somerville
# Marilyn McCord Adams
# Mario Bunge
# Mario Kopić
# Mario Tronti
# Marquis de Sade
# Marsilius of Inghen
# Martha Nussbaum
# Martin Buber
# Martin Davis
# Martin Heidegger
# Martin Luther King, Jr.
# Martin Löb
# Martin Rees
# Martin Stokhof
# Mary Daly
# Matthew Foreman
# Maurice Blanchot
# Maurice Brinton
# Maurice Cranston
# Max Baginski
# Max Black
# Max Horkheimer
# Max Scheler
# Max Stirner
# Mazdak
# Mazen Asfour
# Melvin Fitting
# Mencius
# Menedemus
# Michael A. E. Dummett
# Michael A. Smith
# Michael Davis (philosopher)
# Michael Devitt
# Michael Fourman
# Michael J. Sandel
# Michael Novak
# Michael O. Rabin
# Michael Oakeshott
# Michael Otsuka
# Michael Sprinker
# Michel Foucault
# Michel Onfray
# Miguel A. De La Torre
# Mihailo Marković
# Mikelis Avlichos
# Mikhail Bakunin
# Milan Kangrga
# Mioara Mugur-Schächter
# Mohandas Gandhi
# Mohandas Karamchand Gandhi
# Mojżesz Presburger
# Monarchomachs
# Monroe Beardsley
# Montesquieu
# Moritz Schlick
# Morris Weitz
# Mortimer Adler
# Moses
# Moses Schönfinkel
# Moshe Chaim Luzzatto
# Moshe Y. Vardi
# Mozi
# Muhammad
# Muhammad Asad
# Muhammad Iqbal
# Murray Bookchin
# Murray Rothbard
# Nader El-Bizri
# Nancy Cartwright (philosopher)
# Nassim Nicholas Taleb
# Nathan Salmon
# Nayef Al-Rodhan
# Nelson Goodman
# Nestor Makhno
# Newton da Costa
# Niccolò Machiavelli
# Nick Bostrom
# Nicolai A. Vasiliev
# Nicolai Hartmann
# Nicolas Bourbaki
# Nicolas Malebranche
# Nigel Warburton
# Niklas Luhmann
# Noam Chomsky
# Nomy Arpaly
# Norbert Bolz
# Norbert Leser
# Norman Daniels
# Norman Malcolm
# Nosson Tzvi Finkel (Slabodka)
# Nuel Belnap
# Nyāya Sūtras
# Octave Mirbeau
# Ogyū Sorai
# Oliver Wendell Holmes, Jr.
# Onora O'Neill, Baroness O'Neill of Bengarve
# Oscar Wilde
# Oskar Negt
# Oswald von Nell-Breuning
# Otto Weininger
# Owen Flanagan
# P. F. Strawson
# Paolo Virno
# Paolo da Pergola
# Parmenides
# Partha Dasgupta
# Paul Benacerraf
# Paul Bernays
# Paul Cohen (mathematician)
# Paul Grice
# Paul Hawken
# Paul Häberlin
# Paul Janet
# Paul Lorenzen
# Paul R. Patton
# Paul Tillich
# Paul Virilio
# Paul of Venice
# Pavel Tichý
# Pekka Himanen
# Penelope Maddy
# Per Bauhn
# Per Martin-Löf
# Peter Abelard
# Peter B. Andrews (mathematician)
# Peter D. Klein
# Peter Geach
# Peter Glassen
# Peter Goldie
# Peter Kivy
# Peter Kropotkin
# Peter Lamborn Wilson
# Peter Lipton
# Peter Ludlow
# Peter Lunenfeld
# Peter Medawar
# Peter Railton
# Peter Singer
# Peter Sloterdijk
# Peter Unger
# Peter of Spain (author)
# Peter van Inwagen
# Petr Hájek
# Petrus Ramus
# Phaleas of Chalcedon
# Philip Doddridge
# Philip Jourdain
# Philip Mazzei
# Philip Pettit
# Philip Wicksteed
# Philippa Foot
# Philippe Van Parijs
# Phillip H. Wiebe
# Philo
# Philo the Dialectician
# Piergiorgio Odifreddi
# Pierre Abélard
# Pierre Bourdieu
# Pierre Teilhard de Chardin
# Pierre-André Taguieff
# Plato
# Plotinus
# Porphyry (philosopher)
# Proclus Lycaeus
# Prodicus
# Protagoras
# Pyotr Novikov
# Pythagoras
# Quintilian
# R. Edward Freeman
# R. G. Collingwood
# R. M. Hare
# Rada Iveković
# Radhakamal Mukerjee
# Raghunatha Siromani
# Raimond Gaita
# Rainer Forst
# Ralph Strode
# Ralph Waldo Emerson
# Ramon Llull
# Randy Cohen
# Raphael M. Robinson
# Raya Dunayevskaya
# Raymond Frey
# Raymond Smullyan
# Reinhold Niebuhr
# René Descartes
# Reuben Louis Goodstein
# Richard Brinkley
# Richard Ferrybridge
# Richard Jeffrey
# Richard Kilvington
# Richard M. Weaver
# Richard Meltzer
# Richard Milton Martin
# Richard Montague
# Richard Price
# Richard Rorty
# Richard Routley
# Richard Shusterman
# Richard Swineshead
# Richard Sylvan
# Richard Whately
# Richard Wollheim
# Richard the Sophister
# Right Hegelians
# Robert Audi
# Robert Kilwardby
# Robert Kowalski
# Robert Lawson Vaught
# Robert M. Solovay
# Robert Merrihew Adams
# Robert Nozick
# Robert P. George
# Robert Paul Wolff
# Robert S. Hartman
# Robert Stalnaker
# Roberto Esposito
# Roberto Mangabeira Unger
# Robin Gandy
# Roderick Long
# Rodolphus Agricola
# Roger Chao
# Roger Crisp
# Roger Scruton
# Roland Barthes
# Roland Fraïssé
# Rolf Schock
# Ronald Dworkin
# Ronald Jensen
# Ronald Paulson
# Ronald Reagan
# Rosalind Hursthouse
# Rudolf Arnheim
# Rudolf Carnap
# Rudolf Christoph Eucken
# Rudolf Steiner
# Rushworth Kidder
# Russ Shafer-Landau
# Russell Kirk
# Ruth Barcan Marcus
# S. Barry Cooper
# Saharon Shelah
# Sally Haslanger
# Sam Murgatroyd
# Samuel Bailey
# Samuel Scheffler
# Sandra Harding
# Saul Kripke
# Saunders MacLane
# Sedulius Scottus
# Serge Moscovici
# Sergei Adian
# Seyyed Hossein Nasr
# Shadworth Hodgson
# Shelly Kagan
# Sherrilyn Roush
# Shmuel Alexandrov
# Siegfried Gottwald
# Simon Critchley
# Simone Weil
# Simone de Beauvoir
# Simplicius of Cilicia
# Slavoj Žižek
# Socrates
# Sol Garfunkel
# Solomon Feferman
# Solomon Passy
# Spencer Heath
# Sri Aurobindo
# Stanisław Jaśkowski
# Stanisław Leśniewski
# Stanley Cavell
# Stanley Grenz
# Stanley Hauerwas
# Stephen Bronner
# Stephen Cole Kleene
# Steven Poole
# Stewart Shapiro
# Stobaeus
# Stuart Wilde
# Sun Yat-sen
# Susan Haack
# Susan Wolf
# Susanna Schellenberg
# Susanna Siegel
# Susanne Langer
# Suzy Kassem
# Swami Vivekananda
# Søren Kierkegaard
# T. H. Irwin
# T. M. Scanlon
# Tadeusz Czeżowski
# Tadeusz Kotarbiński
# Takis Fotopoulos
# Tan Sitong
# Tara Smith (philosopher)
# Tenzin Gyatso
# Terence McKenna
# Terence Parsons
# Theodor Mundt
# Theodor Sternberg
# Theodor W. Adorno
# Theodor Zwinger
# Theodore Sider
# Theodore Slaman
# Theophrastus
# Thiruvalluvar
# Thomas Aquinas
# Thomas Berry
# Thomas Bradwardine
# Thomas Henry Huxley
# Thomas Hill Green
# Thomas Hobbes
# Thomas Nagel
# Thomas Reid
# Thoralf Skolem
# Thucydides
# Théodore Simon Jouffroy
# Todd May
# Toju Nakae
# Tom Beauchamp
# Tom Regan
# Tomek Pietkiewicz
# Tony Honoré
# Trenton Merricks
# Tripp York
# Tudor Vianu
# Udayana
# Umar bin al-Khattab
# Umberto Eco
# Valentin Feldman
# Vernon Lee
# Victor Basch
# Victor Cousin
# Victor Gollancz
# Virgil Aldrich
# Vissarion Belinsky
# Vladimir Andreyevich Uspensky
# Voltaire
# Voltairine de Cleyre
# W. D. Ross
# W. Hugh Woodin
# W.K. Wimsatt
# W.V.O. Quine
# Walter Benjamin
# Walter Burley
# Walter Pater
# Walter Pitts
# Walter Terence Stace
# Warren Buffett
# Wau Holland
# Wesley J. Smith
# Wesley Newcomb Hohfeld
# Wilhelm Ackermann
# Wilhelm Dilthey
# Willard V. O. Quine
# Willard Van Orman Quine
# William Alston
# William Alvin Howard
# William C. Dowling
# William Craig (logician)
# William Ernest Johnson
# William Fontaine
# William George Ward
# William James
# William K. Frankena
# William Lycan
# William Paley
# William Stanley Jevons
# William Sweet
# William Whewell
# William Wollaston
# William of Ockham
# William of Sherwood
# Wolfgang Smith
# Wu Enyu
# Xavier Zubiri
# Xenocrates
# Xenophanes
# Xun Kuang
# Xun Zi
# Yamaga Sokō
# Yamazaki Ansai
# Yehoshua Bar-Hillel
# Yi I
# Yiannis N. Moschovakis
# Young Hegelians
# Yuri Matiyasevich
# Yusuf Balasagun
# Yves Marie André
# Zalman Schachter-Shalomi
# Zeno of Elea
# Zhuang Zhou
# Ziauddin Sardar
# Étienne de La Boétie
# Þorsteinn Gylfason
# İoanna Kuçuradi

# %%
import pickle
import urllib

# Run through all philosophers' links
all_phil = {}

for phil in trim_phil:
    baseurl    = "https://en.wikipedia.org/w/api.php?" # ensure English wiki
    if(phil.startswith(":")):
        # Redirect to right page if no English available
        cc = re.search(r'^:([a-zA-Z]+):',phil).group(1)
        phil = re.sub(r'^:([a-zA-Z]+):','',phil)
        baseurl = "https://%s.wikipedia.org/w/api.php?" % (cc)
    
    # Create query
    print phil
    phil_q = urllib.quote(phil.replace(" ","_"))
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+phil_q,content,dataformat)
    print query
    f = urllib2.urlopen(query)
    phil_all_links = re.findall(r'\[\[([^\]|]+)\|?[^\]]*\]\]',f.read())
    
    # Drop all but philosopher's links 
    # phil_links = [val for val in phil_all_links if val in trim_phil]
    for item in phil_all_links:
        for item2 in trim_phil:
            try:
                if item == item2.astype('U'):
                    item = item2
            except UnicodeDecodeError:
                print item, type(item)
                print item2, type(item2)
                
    
    # Save Philosopher's links
    all_phil[phil] = phil_links

phil_out = open('philosophers_associativity_list.pkl','wb')
pickle.dump(all_phil, phil_out, pickle.HIGHEST_PROTOCOL)
# Out:
# Martinus Dorpius
# https://nl.wikipedia.org/w/api.php?action=query&titles=Martinus_Dorpius&prop=revisions&rvprop=content&format=json&utf8=
# A. J. Ayer
# https://en.wikipedia.org/w/api.php?action=query&titles=A._J._Ayer&prop=revisions&rvprop=content&format=json&utf8=
# C:\Users\frksteenhoff\Anaconda2\lib\site-packages\ipykernel\__main__.py:28: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
# Abraham Fraenkel
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Fraenkel&prop=revisions&rvprop=content&format=json&utf8=
# Abraham Joshua Heschel
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Joshua_Heschel&prop=revisions&rvprop=content&format=json&utf8=
# Abraham Robinson
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Robinson&prop=revisions&rvprop=content&format=json&utf8=
# Abraham ibn Daud
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_ibn_Daud&prop=revisions&rvprop=content&format=json&utf8=
# Abul Kalam Azad
# https://en.wikipedia.org/w/api.php?action=query&titles=Abul_Kalam_Azad&prop=revisions&rvprop=content&format=json&utf8=
# Adam Müller
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-297-f35b3b539093> in <module>()
#      15     # Create query
#      16     print phil
# ---> 17     phil_q = urllib.quote(phil.replace(" ","_"))
#      18     query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+phil_q,content,dataformat)
#      19     print query
#
# C:\Users\frksteenhoff\Anaconda2\lib\urllib.pyc in quote(s, safe)
#    1297     if not s.rstrip(safe):
#    1298         return s
# -> 1299     return ''.join(map(quoter, s))
#    1300
#    1301 def quote_plus(s, safe=''):
#
# KeyError: u'\xfc'

# %% [markdown]
# ## Other
