# %% [markdown]
# # Assigment 1
# *The exercises have been solved in collaboration between the following students:*
# * Christian Kjær, s124324
# * Kristiam Dam-Jensen, s113103
# * Henriette Steenhoff, s134869

# %% [markdown]
# ## Part One: Network Models

# %% [markdown]
# ### Watts-Strogatz Networks

# %% [markdown]
# * __Use nx.watts_strogatz_graph to generate 3 graphs with 500 nodes each, average degree = 4, and rewiring probablity p = 0, 0.1, and 1. Calculate the average shortest path length < d > for each one.__

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# Initializing the graphs
G1 = nx.watts_strogatz_graph(500,4,0.0)
G2 = nx.watts_strogatz_graph(500,4,0.1)
G3 = nx.watts_strogatz_graph(500,4,1)

# Calculation of average shortest path lenght
print "Average shortest path G1: ", nx.average_shortest_path_length(G1)
print "Average shortest path G2: ", nx.average_shortest_path_length(G2)
print "Average shortest path G3: ", nx.average_shortest_path_length(G3)
# Out:
# Average shortest path G1:  62.875751503
# Average shortest path G2:  7.8450260521
# Average shortest path G3:  4.74180360721

# %%
# Plot the networks to visualize the difference 
nx.draw_spring(G1,node_size=20,node_color='#B23AEE',scale=1)
plt.show()
nx.draw_spring(G2,node_size=20,node_color='#B23AEE',scale=1)
plt.show()
nx.draw_spring(G3,node_size=20,node_color='#B23AEE',scale=1)
plt.show()

# %% [markdown]
# **What happens to the network when $p = 1$?**
#
# When $p = 1$ the probability that there exist a link between any of the nodes in the graph is $100\%$ which means that all nodes are connected. Thus we get a giant component.

# %%
# Creating the 500 networks
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

k = 4
nodes = 500
ps = [0, 0.01, 0.03, 0.05, 0.1, 0.2]

std_deviations = []
shortest_path_averages = []
for p in ps:
    averages = []
    # Generating the 50 networks
    for i in range(0, 50):
        # With 500 nodes
        G = nx.watts_strogatz_graph(nodes, k, p)
        averages.append(nx.average_shortest_path_length((G)))
    std_deviations.append(np.array(averages).std())
    shortest_path_averages.append(np.array(averages).mean())

plt.grid(True)
plt.title("Decrease in path length")
plt.errorbar(ps, shortest_path_averages, yerr=std_deviations)
plt.show()

# %% [markdown]
# ### The Barabasi-Albert Model

# %% [markdown]
# The 100 node network

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# Graph of one single link between two nodes
G1 = nx.Graph()
G1.add_nodes_from([0,1])
G1.add_edge(0,1)
n = 100 # number of final nodes, nice way to look at different examples


# Repeating the action until 100 nodes
for ii in range(0,n):
    # Making flat list with list comprehension
    num_list = G1.edges()
    flat_list = [num for elem in num_list for num in elem]

    # Adding new node and choosing random link
    G1.add_node(ii)
    G1.add_edge(ii,random.choice(flat_list)) 

# Draw graph
nx.draw_spring(G1,node_size=20,node_color='#B23AEE',scale=2)
plt.show()

# The easy way
#G = nx.barabasi_albert_graph(100,99)

# %% [markdown]
# The 5000 node network

# %%
# Graph of one single link between two nodes
G1 = nx.Graph()
G1.add_nodes_from([0,1])
G1.add_edge(0,1)
flat_list = []
n = 5000 # number of final nodes, nice way to look at different examples


# Repeating the action until 100 nodes
for ii in range(0,n):
    # Making flat list with list comprehension
    num_list = G1.edges()
    flat_list = [num for elem in num_list for num in elem]

    # Adding new node and choosing random link
    G1.add_node(ii)
    G1.add_edge(ii,random.choice(flat_list)) 

# Draw graph
nx.draw_spring(G1,node_size=1,width=0.1,node_color='#B23AEE',scale=2)
plt.show()

# The easy way
#G = nx.barabasi_albert_graph(100,99)

# %%
from collections import Counter
# Find min and max values (from histogram it should be among the lower numbers)
c = Counter(flat_list)
print("Max degrees: " + str(max(c.values())))
print("Min degrees: " + str(min(c.values())))
# Out:
# Max degrees: 204
# Min degrees: 1

# %%
import numpy as np

labels, values = zip(*Counter(flat_list).items())
# Plot the binned degree distribution
# Bin size based on max degree.
plt.hist(values,bins=max(c.values()))

# For readability
plt.grid(True)
plt.title("Barabasi Strogatz Network, 5000 nodes")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# And now with logarithmic x & y axis
plt.hist(values,bins=max(c.values()))
plt.title("Barabasi Strogatz Network, 5000 nodes log-log")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### The Power-laws and the Friendship Paradox

# %% [markdown]
# - Pick a node i at random (e.g. use random.choice). Find its degree.
# - Find i's neighbors. And calculate their average degree.
# - Compare the two numbers to check if it's true that i's friends (on average) have more friends than i.*description*

# %%
import random

# Network manipulation - friendship paradox
# Using the graph from the previous exercise
total = 0
n = 1000
avg_cnt = 0

for ii in range(0,n):
    rand_node = random.choice(flat_list)
    print "Node:                 ", rand_node
    # Degree of random node
    print "Degree:               ", G1.degree(rand_node)
    # Neighbors of the random node
    print "Neighbors:            ", G1.neighbors(rand_node)
    
    # Find degrees of neighboring nodes
    for neighbor in G1.neighbors(rand_node):
        avg_cnt = avg_cnt + G1.degree(neighbor)
    # Check whether the average degree is less than or greater than rand node
    if(avg_cnt/len(G1.neighbors(rand_node)) > G1.degree(rand_node)):
        total = total + 1 
        print "Avg degree neighbors: ", avg_cnt/len(G1.neighbors(rand_node))
    avg_cnt = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ae11e41971ae> in <module>()
#       8
#       9 for ii in range(0,n):
# ---> 10     rand_node = random.choice(flat_list)
#      11     print "Node:                 ", rand_node
#      12     # Degree of random node
#
# NameError: name 'flat_list' is not defined

# %%
# Print result
print "The paradox is true ", total, " times out of", n
# Out:
# The paradox is true  584  times out of 1000

# %% [markdown]
# The friendship paradox is true roughly half the time after running a thousand simulations.

# %% [markdown]
# ### Growth without Preferential Attachment

# %% [markdown]
# Compare the network you've just built to the ER network of same size and same p. What are the differences?

# %%
import networkx as nx
# New graph, same procedure

G5 = nx.erdos_renyi_graph(5000,0.15)
total = 0

for ii in range(0,n):
    rand_node = random.randint(0,4999)
    print "Node:                 ", rand_node
    # Degree of random node
    print "Degree:               ", G5.degree(rand_node)
    # Neighbors of the random node
    print "Neighbors:            ", G5.neighbors(rand_node)
    
    # Find degrees of neighboring nodes
    for neighbor in G5.neighbors(rand_node):
        avg_cnt = avg_cnt + G5.degree(neighbor)
    # Check whether the average degree is less than or greater than rand node
    if(avg_cnt/len(G5.neighbors(rand_node)) > G5.degree(rand_node)):
        total = total + 1 
        #print "Avg degree neighbors: ", avg_cnt/len(G5.neighbors(rand_node))
    avg_cnt = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ac8a5729bbbd> in <module>()
#       5 total = 0
#       6
# ----> 7 for ii in range(0,n):
#       8     rand_node = random.randint(0,4999)
#       9     print "Node:                 ", rand_node
#
# NameError: name 'n' is not defined

# %%
# Print result
print "The paradox is true ", total, " times out of", n

# %% [markdown]
# The paradox is not true on average.

# %% [markdown]
# ## Part Two: The Wikipedia Philosopher's Network

# %% [markdown]
# ### Basic Statistics

# %% [markdown]
# **Philosophers in each list **

# %%
import re
import urllib2
import json
import numpy as np
response = urllib2.urlopen('https://en.wikipedia.org/wiki/List_of_aestheticians')
html = response.read()

# %%
# Getting the philosopher informatiom
baseurl    = "https://en.wikipedia.org/w/api.php?"
action     = "action=query"
title      = "titles="
content    = "prop=revisions&rvprop=content"
dataformat = "format=json"

# List of all Philosophers by core area
list_phil = ['List_of_aestheticians','List_of_epistemologists','List_of_ethicists','List_of_logicians','List_of_metaphysicians','List_of_social_and_political_philosophers']
query = []     # current query to process
phil_count = 0 # accumulated count of philosophers in each group
all_phil = []  # final list of all philosophers

# constructing query for getting all Philosopher data
for core_area in list_phil:
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+core_area,content,dataformat)

    f = urllib2.urlopen(query)
    area_links = re.findall(r'\*.?\[\[([^\]|]+)\|?[^\]]*\]\]',f.read())
    trim_area_links = [item for item in area_links if not item.lower().startswith('list of')]
    all_phil.extend(trim_area_links)
    print "Query for:", core_area
    print (query)
    print "Number of philosophers: ", len(trim_area_links)
    print
    #print trim_area_links
    
    # Accumulate number of philosophers
    phil_count = phil_count + len(trim_area_links)

all_phil = sorted(all_phil)
print "Philosophers in all: ", phil_count
# Out:
# Query for: List_of_aestheticians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_aestheticians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  124
#
# Query for: List_of_epistemologists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_epistemologists&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  98
#
# Query for: List_of_ethicists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_ethicists&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  272
#
# Query for: List_of_logicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_logicians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  271
#
# Query for: List_of_metaphysicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_metaphysicians&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  96
#
# Query for: List_of_social_and_political_philosophers
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_social_and_political_philosophers&prop=revisions&rvprop=content&format=json&utf8=
# Number of philosophers:  294
#
# Philosophers in all:  1155

# %% [markdown]
# **Which is the largest branch of philosophy?**
#
# Judging by the number of philosophers in the different groups from the exercise above, the philosophers within **social and political philosophy** is the greatest branch with 294 philosophers. They are closely followed by Logicians and Ethicists.

# %% [markdown]
# **Philosophers in several lists?**
#
# To solve this problem it is easiest to use the list of all philosophers **all_phil**. This has been slightly modified such that only unique values remain.

# %%
from collections import Counter
in_several_lists = Counter(all_phil)

# Print most popular philosopher
print "Philosopher in most lists: "
print in_several_lists.most_common(1)

## The list of all unique philosophers
unique_all_phil = np.unique(all_phil)

## Printing the values
#for philosopher in unique_all_phil.flat:
#    print(philosopher)
# Out:
# Philosopher in most lists:
# [('Aristotle', 6)]

# %% [markdown]
# **Philosophers in several sub-fields**
#
# To solve this problem it is easiest to use the list of all philosophers. To see whether they are in several lists, one need to look at the list with all names, where none has been removed to avoid duplication.

# %% [markdown]
# **List of every philosopher occuring in more than one list descendingly**

# %%
import operator

popular_phil = {}
temp = dict(Counter(in_several_lists))

# Getting the values of philosophers in lists > 1
for key, value in temp.iteritems():
    if value > 1:
        popular_phil[key] = value

        # Sort by occurences and print the philosophers
sorted_phil = sorted(popular_phil.items(), key=lambda x: (-x[1], x[0]))
print '\n'.join(map(str, sorted_phil))
# Out:
# ('Aristotle', 6)
# ('Bertrand Russell', 5)
# ('Immanuel Kant', 5)
# ('Plato', 5)
# ('Ayn Rand', 4)
# ('Arthur Schopenhauer', 3)
# ('David Hume', 3)
# ('Georg Wilhelm Friedrich Hegel', 3)
# ('Gottfried Leibniz', 3)
# ('John Locke', 3)
# ('John Stuart Mill', 3)
# ('Judith Butler', 3)
# ('Ludwig Wittgenstein', 3)
# ('Mario Bunge', 3)
# ('Nelson Goodman', 3)
# ('Ruth Barcan Marcus', 3)
# ('Susan Haack', 3)
# ('S\xc3\xb8ren Kierkegaard', 3)
# ('Thomas Aquinas', 3)
# ('Abraham Joshua Heschel', 2)
# ('Alain Badiou', 2)
# ('Alfred North Whitehead', 2)
# ('Alvin Plantinga', 2)
# ('B. R. Ambedkar', 2)
# ('Baruch Spinoza', 2)
# ('Berit Brogaard', 2)
# ('Catherine Elgin', 2)
# ('Christian Wolff (philosopher)', 2)
# ('Confucius', 2)
# ('Constantin R\xc4\x83dulescu-Motru', 2)
# ('David Chalmers', 2)
# ('David Kolb', 2)
# ('Edward Said', 2)
# ('Emma Goldman', 2)
# ('Francis Bacon', 2)
# ('Francis Hutcheson (philosopher)', 2)
# ('Friedrich Nietzsche', 2)
# ('Friedrich Schiller', 2)
# ('G. E. Moore', 2)
# ('George Berkeley', 2)
# ('George Boole', 2)
# ('Georges Bataille', 2)
# ('Giambattista Vico', 2)
# ('Gilbert Harman', 2)
# ('Gottlob Frege', 2)
# ('Graham Priest', 2)
# ('Gualtiero Piccinini', 2)
# ('Henry Sidgwick', 2)
# ('Herbert Spencer', 2)
# ('Hilary Putnam', 2)
# ('Hugo Grotius', 2)
# ('J. J. C. Smart', 2)
# ('Jean-Fran\xc3\xa7ois Lyotard', 2)
# ('Jean-Jacques Rousseau', 2)
# ('Jeremy Bentham', 2)
# ('Jessica Wilson', 2)
# ('John Finnis', 2)
# ('John Hawthorne', 2)
# ('John Hospers', 2)
# ('John Rawls', 2)
# ('John Ruskin', 2)
# ('John Searle', 2)
# ('Joseph Raz', 2)
# ('Joxe Azurmendi', 2)
# ('Judith Jarvis Thomson', 2)
# ('J\xc3\xbcrgen Habermas', 2)
# ('Karl Popper', 2)
# ('Karl Wilhelm Friedrich von Schlegel', 2)
# ('Karl-Otto Apel', 2)
# ('Kit Fine', 2)
# ('L.A. Paul', 2)
# ('Lorenzo Pe\xc3\xb1a', 2)
# ('Ludwig von Mises', 2)
# ('Mao Zedong', 2)
# ('Martha Nussbaum', 2)
# ('Martin Heidegger', 2)
# ('Martin Luther King, Jr.', 2)
# ('Maurice Blanchot', 2)
# ('Max Stirner', 2)
# ('Mencius', 2)
# ('Michael Oakeshott', 2)
# ('Michel Foucault', 2)
# ('Michel Onfray', 2)
# ('Mortimer Adler', 2)
# ('Mozi', 2)
# ('Murray Bookchin', 2)
# ('Murray Rothbard', 2)
# ('Nader El-Bizri', 2)
# ('Niccol\xc3\xb2 Machiavelli', 2)
# ('Noam Chomsky', 2)
# ('P. F. Strawson', 2)
# ('Paul Benacerraf', 2)
# ('Paul of Venice', 2)
# ('Penelope Maddy', 2)
# ('Peter Geach', 2)
# ('Peter Kropotkin', 2)
# ('Peter Unger', 2)
# ('Peter of Spain (author)', 2)
# ('Philip Pettit', 2)
# ('Ren\xc3\xa9 Descartes', 2)
# ('Robert Nozick', 2)
# ('Robert S. Hartman', 2)
# ('Ronald Dworkin', 2)
# ('Sally Haslanger', 2)
# ('Saul Kripke', 2)
# ('Socrates', 2)
# ('Sun Yat-sen', 2)
# ('T. M. Scanlon', 2)
# ('Thomas Hill Green', 2)
# ('Thomas Hobbes', 2)
# ('Thomas Nagel', 2)
# ('Trenton Merricks', 2)
# ('Walter Benjamin', 2)
# ('Walter Terence Stace', 2)
# ('William Alston', 2)
# ('William of Ockham', 2)

# %% [markdown]
# **Print of the top 5 guys**

# %%
print in_several_lists.most_common(5)
# Out:
# [('Aristotle', 6), ('Plato', 5), ('Bertrand Russell', 5), ('Immanuel Kant', 5), ('Ayn Rand', 4)]

# %% [markdown]
# * *Have you heard of any of them?*
#
# Yes, we know Aristotle, Plato, Russell and Kant.

# %% [markdown]
# ### Degree Distribution

# %% [markdown]
# #### Creating the philosopher's network
# *Before answering the exercises, the network of the philosopher's will be created as shown below. This will be the basis for the following answers.*
#
# For **pickling** and **unpickling** of our data we used the *networkx.readwrite.gpickle* [documentation](https://networkx.github.io/documentation/development/_modules/networkx/readwrite/gpickle.html).

# %%
import cPickle as pickle
import urllib

links = {} # list of list with all links between philosophers

# Run through all philosophers' links
for phil in unique_all_phil:
    baseurl    = "https://en.wikipedia.org/w/api.php?" # ensure English wiki
    if(phil.startswith(":")):
        # Redirect to right page if no English available
        cc = re.search(r'^:([a-zA-Z]+):',phil).group(1)
        phil = re.sub(r'^:([a-zA-Z]+):','',phil)
        baseurl = "https://%s.wikipedia.org/w/api.php?" % (cc)
    
    # Create query
    phil_q = urllib.quote(phil.replace(" ","_"))
    print phil_q
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+phil_q,content,dataformat)
    print query
    f = urllib2.urlopen(query)
    phil_all_links = re.findall(r'\[\[([^\]|]+)\|?[^\]]*\]\]',f.read())
    
    # Drop all but philosopher's links 
    phil_links = [val for val in phil_all_links if val in unique_all_phil]
    #print phil_links   # see all links             
    
    # Save Philosopher's links
    links[phil] = phil_links


with open("phil_test.pkl", "wb") as f:
    pickle.dump(links, f)
# Out:
# Martinus_Dorpius
# https://nl.wikipedia.org/w/api.php?action=query&titles=Martinus_Dorpius&prop=revisions&rvprop=content&format=json&utf8=
# A._J._Ayer
# https://en.wikipedia.org/w/api.php?action=query&titles=A._J._Ayer&prop=revisions&rvprop=content&format=json&utf8=
# Abraham_Fraenkel
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Fraenkel&prop=revisions&rvprop=content&format=json&utf8=
# Abraham_Joshua_Heschel
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Joshua_Heschel&prop=revisions&rvprop=content&format=json&utf8=
# Abraham_Robinson
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_Robinson&prop=revisions&rvprop=content&format=json&utf8=
# Abraham_ibn_Daud
# https://en.wikipedia.org/w/api.php?action=query&titles=Abraham_ibn_Daud&prop=revisions&rvprop=content&format=json&utf8=
# Abul_Kalam_Azad
# https://en.wikipedia.org/w/api.php?action=query&titles=Abul_Kalam_Azad&prop=revisions&rvprop=content&format=json&utf8=
# Adam_M%C3%BCller
# https://en.wikipedia.org/w/api.php?action=query&titles=Adam_M%C3%BCller&prop=revisions&rvprop=content&format=json&utf8=
# Adam_Smith
# https://en.wikipedia.org/w/api.php?action=query&titles=Adam_Smith&prop=revisions&rvprop=content&format=json&utf8=
# Adolf_Lindenbaum
# https://en.wikipedia.org/w/api.php?action=query&titles=Adolf_Lindenbaum&prop=revisions&rvprop=content&format=json&utf8=
# Adrian_Johnston_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Adrian_Johnston_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Ahmed_Raza_Khan
# https://en.wikipedia.org/w/api.php?action=query&titles=Ahmed_Raza_Khan&prop=revisions&rvprop=content&format=json&utf8=
# Alain_Badiou
# https://en.wikipedia.org/w/api.php?action=query&titles=Alain_Badiou&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Bundy
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Bundy&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Carter_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Carter_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Gewirth
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Gewirth&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Ross_Anderson
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Ross_Anderson&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Ryan
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Ryan&prop=revisions&rvprop=content&format=json&utf8=
# Alan_Turing
# https://en.wikipedia.org/w/api.php?action=query&titles=Alan_Turing&prop=revisions&rvprop=content&format=json&utf8=
# Alasdair_MacIntyre
# https://en.wikipedia.org/w/api.php?action=query&titles=Alasdair_MacIntyre&prop=revisions&rvprop=content&format=json&utf8=
# Alasdair_Urquhart
# https://en.wikipedia.org/w/api.php?action=query&titles=Alasdair_Urquhart&prop=revisions&rvprop=content&format=json&utf8=
# Alastair_Norcross
# https://en.wikipedia.org/w/api.php?action=query&titles=Alastair_Norcross&prop=revisions&rvprop=content&format=json&utf8=
# Albert_Camus
# https://en.wikipedia.org/w/api.php?action=query&titles=Albert_Camus&prop=revisions&rvprop=content&format=json&utf8=
# Albert_Schweitzer
# https://en.wikipedia.org/w/api.php?action=query&titles=Albert_Schweitzer&prop=revisions&rvprop=content&format=json&utf8=
# Albert_of_Saxony_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Albert_of_Saxony_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Alcuin
# https://en.wikipedia.org/w/api.php?action=query&titles=Alcuin&prop=revisions&rvprop=content&format=json&utf8=
# Aldo_Leopold
# https://en.wikipedia.org/w/api.php?action=query&titles=Aldo_Leopold&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Bain
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Bain&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Campbell_Fraser
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Campbell_Fraser&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Esenin-Volpin
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Esenin-Volpin&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Gerard
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Gerard&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Gottlieb_Baumgarten
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Gottlieb_Baumgarten&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_S._Kechris
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_S._Kechris&prop=revisions&rvprop=content&format=json&utf8=
# Alexander_Zinoviev
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexander_Zinoviev&prop=revisions&rvprop=content&format=json&utf8=
# Alexis_de_Tocqueville
# https://en.wikipedia.org/w/api.php?action=query&titles=Alexis_de_Tocqueville&prop=revisions&rvprop=content&format=json&utf8=
# Alfred_Horn
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Horn&prop=revisions&rvprop=content&format=json&utf8=
# Alfred_North_Whitehead
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_North_Whitehead&prop=revisions&rvprop=content&format=json&utf8=
# Alfred_Rosenberg
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Rosenberg&prop=revisions&rvprop=content&format=json&utf8=
# Alfred_Tarski
# https://en.wikipedia.org/w/api.php?action=query&titles=Alfred_Tarski&prop=revisions&rvprop=content&format=json&utf8=
# Algernon_Charles_Swinburne
# https://en.wikipedia.org/w/api.php?action=query&titles=Algernon_Charles_Swinburne&prop=revisions&rvprop=content&format=json&utf8=
# Ali_Shariati
# https://en.wikipedia.org/w/api.php?action=query&titles=Ali_Shariati&prop=revisions&rvprop=content&format=json&utf8=
# Alice_Crary
# https://en.wikipedia.org/w/api.php?action=query&titles=Alice_Crary&prop=revisions&rvprop=content&format=json&utf8=
# Alija_Izetbegovi%C4%87
# https://en.wikipedia.org/w/api.php?action=query&titles=Alija_Izetbegovi%C4%87&prop=revisions&rvprop=content&format=json&utf8=
# Allan_Gibbard
# https://en.wikipedia.org/w/api.php?action=query&titles=Allan_Gibbard&prop=revisions&rvprop=content&format=json&utf8=
# Alon_Ben-Meir
# https://en.wikipedia.org/w/api.php?action=query&titles=Alon_Ben-Meir&prop=revisions&rvprop=content&format=json&utf8=
# Alonzo_Church
# https://en.wikipedia.org/w/api.php?action=query&titles=Alonzo_Church&prop=revisions&rvprop=content&format=json&utf8=
# Alvin_Goldman
# https://en.wikipedia.org/w/api.php?action=query&titles=Alvin_Goldman&prop=revisions&rvprop=content&format=json&utf8=
# Alvin_Plantinga
# https://en.wikipedia.org/w/api.php?action=query&titles=Alvin_Plantinga&prop=revisions&rvprop=content&format=json&utf8=
# Amartya_Sen
# https://en.wikipedia.org/w/api.php?action=query&titles=Amartya_Sen&prop=revisions&rvprop=content&format=json&utf8=
# Ambrose
# https://en.wikipedia.org/w/api.php?action=query&titles=Ambrose&prop=revisions&rvprop=content&format=json&utf8=
# Anandavardhana
# https://en.wikipedia.org/w/api.php?action=query&titles=Anandavardhana&prop=revisions&rvprop=content&format=json&utf8=
# Anaximander
# https://en.wikipedia.org/w/api.php?action=query&titles=Anaximander&prop=revisions&rvprop=content&format=json&utf8=
# Andrea_Bonom%C3%AC
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrea_Bonom%C3%AC&prop=revisions&rvprop=content&format=json&utf8=
# Andreas_Linder
# https://en.wikipedia.org/w/api.php?action=query&titles=Andreas_Linder&prop=revisions&rvprop=content&format=json&utf8=
# Andrei_Marga
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrei_Marga&prop=revisions&rvprop=content&format=json&utf8=
# Andronicus_of_Rhodes
# https://en.wikipedia.org/w/api.php?action=query&titles=Andronicus_of_Rhodes&prop=revisions&rvprop=content&format=json&utf8=
# Andrzej_Mostowski
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrzej_Mostowski&prop=revisions&rvprop=content&format=json&utf8=
# Andrzej_Tadeusz_Kijowski
# https://en.wikipedia.org/w/api.php?action=query&titles=Andrzej_Tadeusz_Kijowski&prop=revisions&rvprop=content&format=json&utf8=
# Andr%C3%A9_Malraux
# https://en.wikipedia.org/w/api.php?action=query&titles=Andr%C3%A9_Malraux&prop=revisions&rvprop=content&format=json&utf8=
# Anne_Conway_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Anne_Conway_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Anne_Sjerp_Troelstra
# https://en.wikipedia.org/w/api.php?action=query&titles=Anne_Sjerp_Troelstra&prop=revisions&rvprop=content&format=json&utf8=
# Anthony_de_Jasay
# https://en.wikipedia.org/w/api.php?action=query&titles=Anthony_de_Jasay&prop=revisions&rvprop=content&format=json&utf8=
# Antoine_Garaby_de_La_Luzerne
# https://en.wikipedia.org/w/api.php?action=query&titles=Antoine_Garaby_de_La_Luzerne&prop=revisions&rvprop=content&format=json&utf8=
# Antonio_Negri
# https://en.wikipedia.org/w/api.php?action=query&titles=Antonio_Negri&prop=revisions&rvprop=content&format=json&utf8=
# Ant%C3%B3nio_Castanheira_Neves
# https://en.wikipedia.org/w/api.php?action=query&titles=Ant%C3%B3nio_Castanheira_Neves&prop=revisions&rvprop=content&format=json&utf8=
# Archon
# https://en.wikipedia.org/w/api.php?action=query&titles=Archon&prop=revisions&rvprop=content&format=json&utf8=
# Arda_Denkel
# https://en.wikipedia.org/w/api.php?action=query&titles=Arda_Denkel&prop=revisions&rvprop=content&format=json&utf8=
# Arend_Heyting
# https://en.wikipedia.org/w/api.php?action=query&titles=Arend_Heyting&prop=revisions&rvprop=content&format=json&utf8=
# Aristotle
# https://en.wikipedia.org/w/api.php?action=query&titles=Aristotle&prop=revisions&rvprop=content&format=json&utf8=
# Aristoxenus
# https://en.wikipedia.org/w/api.php?action=query&titles=Aristoxenus&prop=revisions&rvprop=content&format=json&utf8=
# Armin_Mohler
# https://en.wikipedia.org/w/api.php?action=query&titles=Armin_Mohler&prop=revisions&rvprop=content&format=json&utf8=
# Arnold_Berleant
# https://en.wikipedia.org/w/api.php?action=query&titles=Arnold_Berleant&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Caplan
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Caplan&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Danto
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Danto&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Linton_Corbin
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Linton_Corbin&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Moeller_van_den_Bruck
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Moeller_van_den_Bruck&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Prior
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Prior&prop=revisions&rvprop=content&format=json&utf8=
# Arthur_Schopenhauer
# https://en.wikipedia.org/w/api.php?action=query&titles=Arthur_Schopenhauer&prop=revisions&rvprop=content&format=json&utf8=
# Ashoka
# https://en.wikipedia.org/w/api.php?action=query&titles=Ashoka&prop=revisions&rvprop=content&format=json&utf8=
# Auberon_Herbert
# https://en.wikipedia.org/w/api.php?action=query&titles=Auberon_Herbert&prop=revisions&rvprop=content&format=json&utf8=
# August_Wilhelm_Schlegel
# https://en.wikipedia.org/w/api.php?action=query&titles=August_Wilhelm_Schlegel&prop=revisions&rvprop=content&format=json&utf8=
# Augustine_of_Hippo
# https://en.wikipedia.org/w/api.php?action=query&titles=Augustine_of_Hippo&prop=revisions&rvprop=content&format=json&utf8=
# Augustus_De_Morgan
# https://en.wikipedia.org/w/api.php?action=query&titles=Augustus_De_Morgan&prop=revisions&rvprop=content&format=json&utf8=
# Austin_Osman_Spare
# https://en.wikipedia.org/w/api.php?action=query&titles=Austin_Osman_Spare&prop=revisions&rvprop=content&format=json&utf8=
# Averroes
# https://en.wikipedia.org/w/api.php?action=query&titles=Averroes&prop=revisions&rvprop=content&format=json&utf8=
# Avicenna
# https://en.wikipedia.org/w/api.php?action=query&titles=Avicenna&prop=revisions&rvprop=content&format=json&utf8=
# Axel_Honneth
# https://en.wikipedia.org/w/api.php?action=query&titles=Axel_Honneth&prop=revisions&rvprop=content&format=json&utf8=
# Ayn_Rand
# https://en.wikipedia.org/w/api.php?action=query&titles=Ayn_Rand&prop=revisions&rvprop=content&format=json&utf8=
# B._F._Skinner
# https://en.wikipedia.org/w/api.php?action=query&titles=B._F._Skinner&prop=revisions&rvprop=content&format=json&utf8=
# B._R._Ambedkar
# https://en.wikipedia.org/w/api.php?action=query&titles=B._R._Ambedkar&prop=revisions&rvprop=content&format=json&utf8=
# Bahmany%C4%81r
# https://en.wikipedia.org/w/api.php?action=query&titles=Bahmany%C4%81r&prop=revisions&rvprop=content&format=json&utf8=
# Bahya_ibn_Paquda
# https://en.wikipedia.org/w/api.php?action=query&titles=Bahya_ibn_Paquda&prop=revisions&rvprop=content&format=json&utf8=
# Bah%C3%A1%27u%27ll%C3%A1h
# https://en.wikipedia.org/w/api.php?action=query&titles=Bah%C3%A1%27u%27ll%C3%A1h&prop=revisions&rvprop=content&format=json&utf8=
# Barron_H._Lerner
# https://en.wikipedia.org/w/api.php?action=query&titles=Barron_H._Lerner&prop=revisions&rvprop=content&format=json&utf8=
# Barry_Stroud
# https://en.wikipedia.org/w/api.php?action=query&titles=Barry_Stroud&prop=revisions&rvprop=content&format=json&utf8=
# Baruch_Spinoza
# https://en.wikipedia.org/w/api.php?action=query&titles=Baruch_Spinoza&prop=revisions&rvprop=content&format=json&utf8=
# Benedetto_Croce
# https://en.wikipedia.org/w/api.php?action=query&titles=Benedetto_Croce&prop=revisions&rvprop=content&format=json&utf8=
# Benjamin_Tucker
# https://en.wikipedia.org/w/api.php?action=query&titles=Benjamin_Tucker&prop=revisions&rvprop=content&format=json&utf8=
# Benjamin_Wiker
# https://en.wikipedia.org/w/api.php?action=query&titles=Benjamin_Wiker&prop=revisions&rvprop=content&format=json&utf8=
# Berit_Brogaard
# https://en.wikipedia.org/w/api.php?action=query&titles=Berit_Brogaard&prop=revisions&rvprop=content&format=json&utf8=
# Bernard_Bolzano
# https://en.wikipedia.org/w/api.php?action=query&titles=Bernard_Bolzano&prop=revisions&rvprop=content&format=json&utf8=
# Bernard_Williams
# https://en.wikipedia.org/w/api.php?action=query&titles=Bernard_Williams&prop=revisions&rvprop=content&format=json&utf8=
# Bertrand_Russell
# https://en.wikipedia.org/w/api.php?action=query&titles=Bertrand_Russell&prop=revisions&rvprop=content&format=json&utf8=
# Bertrand_de_Jouvenel
# https://en.wikipedia.org/w/api.php?action=query&titles=Bertrand_de_Jouvenel&prop=revisions&rvprop=content&format=json&utf8=
# Bjarni_J%C3%B3nsson
# https://en.wikipedia.org/w/api.php?action=query&titles=Bjarni_J%C3%B3nsson&prop=revisions&rvprop=content&format=json&utf8=
# Blaise_Pascal
# https://en.wikipedia.org/w/api.php?action=query&titles=Blaise_Pascal&prop=revisions&rvprop=content&format=json&utf8=
# Bob_Meyer_%28logician%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Bob_Meyer_%28logician%29&prop=revisions&rvprop=content&format=json&utf8=
# Boethius
# https://en.wikipedia.org/w/api.php?action=query&titles=Boethius&prop=revisions&rvprop=content&format=json&utf8=
# Boris_Furlan
# https://en.wikipedia.org/w/api.php?action=query&titles=Boris_Furlan&prop=revisions&rvprop=content&format=json&utf8=
# Brian_Leftow
# https://en.wikipedia.org/w/api.php?action=query&titles=Brian_Leftow&prop=revisions&rvprop=content&format=json&utf8=
# Bruce_Lee
# https://en.wikipedia.org/w/api.php?action=query&titles=Bruce_Lee&prop=revisions&rvprop=content&format=json&utf8=
# Bruno_Leoni
# https://en.wikipedia.org/w/api.php?action=query&titles=Bruno_Leoni&prop=revisions&rvprop=content&format=json&utf8=
# Bryan_Caplan
# https://en.wikipedia.org/w/api.php?action=query&titles=Bryan_Caplan&prop=revisions&rvprop=content&format=json&utf8=
# C._D._Broad
# https://en.wikipedia.org/w/api.php?action=query&titles=C._D._Broad&prop=revisions&rvprop=content&format=json&utf8=
# Calvin_Seerveld
# https://en.wikipedia.org/w/api.php?action=query&titles=Calvin_Seerveld&prop=revisions&rvprop=content&format=json&utf8=
# Cameron_Breen
# https://en.wikipedia.org/w/api.php?action=query&titles=Cameron_Breen&prop=revisions&rvprop=content&format=json&utf8=
# Carew_Arthur_Meredith
# https://en.wikipedia.org/w/api.php?action=query&titles=Carew_Arthur_Meredith&prop=revisions&rvprop=content&format=json&utf8=
# Carl_Joachim_Friedrich
# https://en.wikipedia.org/w/api.php?action=query&titles=Carl_Joachim_Friedrich&prop=revisions&rvprop=content&format=json&utf8=
# Carl_Schmitt
# https://en.wikipedia.org/w/api.php?action=query&titles=Carl_Schmitt&prop=revisions&rvprop=content&format=json&utf8=
# Carlo_Lottieri
# https://en.wikipedia.org/w/api.php?action=query&titles=Carlo_Lottieri&prop=revisions&rvprop=content&format=json&utf8=
# Carlos_Santiago_Nino
# https://en.wikipedia.org/w/api.php?action=query&titles=Carlos_Santiago_Nino&prop=revisions&rvprop=content&format=json&utf8=
# Carol_Gilligan
# https://en.wikipedia.org/w/api.php?action=query&titles=Carol_Gilligan&prop=revisions&rvprop=content&format=json&utf8=
# Carrie_Ichikawa_Jenkins
# https://en.wikipedia.org/w/api.php?action=query&titles=Carrie_Ichikawa_Jenkins&prop=revisions&rvprop=content&format=json&utf8=
# Carveth_Read
# https://en.wikipedia.org/w/api.php?action=query&titles=Carveth_Read&prop=revisions&rvprop=content&format=json&utf8=
# Catherine_Elgin
# https://en.wikipedia.org/w/api.php?action=query&titles=Catherine_Elgin&prop=revisions&rvprop=content&format=json&utf8=
# Cesare_Brandi
# https://en.wikipedia.org/w/api.php?action=query&titles=Cesare_Brandi&prop=revisions&rvprop=content&format=json&utf8=
# Chanakya
# https://en.wikipedia.org/w/api.php?action=query&titles=Chanakya&prop=revisions&rvprop=content&format=json&utf8=
# Charles_Blattberg
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Blattberg&prop=revisions&rvprop=content&format=json&utf8=
# Charles_Parsons_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Parsons_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Charles_Sanders_Peirce
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Sanders_Peirce&prop=revisions&rvprop=content&format=json&utf8=
# Charles_Stevenson
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Stevenson&prop=revisions&rvprop=content&format=json&utf8=
# Charles_Taylor_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Charles_Taylor_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Cha%C3%AFm_Perelman
# https://en.wikipedia.org/w/api.php?action=query&titles=Cha%C3%AFm_Perelman&prop=revisions&rvprop=content&format=json&utf8=
# Cheng_Hao
# https://en.wikipedia.org/w/api.php?action=query&titles=Cheng_Hao&prop=revisions&rvprop=content&format=json&utf8=
# Cheng_Yi_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Cheng_Yi_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Christian_Wolff_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Christian_Wolff_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Christine_Korsgaard
# https://en.wikipedia.org/w/api.php?action=query&titles=Christine_Korsgaard&prop=revisions&rvprop=content&format=json&utf8=
# Christine_Ladd-Franklin
# https://en.wikipedia.org/w/api.php?action=query&titles=Christine_Ladd-Franklin&prop=revisions&rvprop=content&format=json&utf8=
# Christopher_Janaway
# https://en.wikipedia.org/w/api.php?action=query&titles=Christopher_Janaway&prop=revisions&rvprop=content&format=json&utf8=
# Chrysippus
# https://en.wikipedia.org/w/api.php?action=query&titles=Chrysippus&prop=revisions&rvprop=content&format=json&utf8=
# Clarence_Irving_Lewis
# https://en.wikipedia.org/w/api.php?action=query&titles=Clarence_Irving_Lewis&prop=revisions&rvprop=content&format=json&utf8=
# Claude_Adrien_Helv%C3%A9tius
# https://en.wikipedia.org/w/api.php?action=query&titles=Claude_Adrien_Helv%C3%A9tius&prop=revisions&rvprop=content&format=json&utf8=
# Claude_Lefort
# https://en.wikipedia.org/w/api.php?action=query&titles=Claude_Lefort&prop=revisions&rvprop=content&format=json&utf8=
# Claude_L%C3%A9vi-Strauss
# https://en.wikipedia.org/w/api.php?action=query&titles=Claude_L%C3%A9vi-Strauss&prop=revisions&rvprop=content&format=json&utf8=
# Claudio_Canaparo
# https://en.wikipedia.org/w/api.php?action=query&titles=Claudio_Canaparo&prop=revisions&rvprop=content&format=json&utf8=
# Clive_Bell
# https://en.wikipedia.org/w/api.php?action=query&titles=Clive_Bell&prop=revisions&rvprop=content&format=json&utf8=
# Colin_Wilson
# https://en.wikipedia.org/w/api.php?action=query&titles=Colin_Wilson&prop=revisions&rvprop=content&format=json&utf8=
# Confucius
# https://en.wikipedia.org/w/api.php?action=query&titles=Confucius&prop=revisions&rvprop=content&format=json&utf8=
# Conimbricenses
# https://en.wikipedia.org/w/api.php?action=query&titles=Conimbricenses&prop=revisions&rvprop=content&format=json&utf8=
# Constantin_R%C4%83dulescu-Motru
# https://en.wikipedia.org/w/api.php?action=query&titles=Constantin_R%C4%83dulescu-Motru&prop=revisions&rvprop=content&format=json&utf8=
# Cora_Diamond
# https://en.wikipedia.org/w/api.php?action=query&titles=Cora_Diamond&prop=revisions&rvprop=content&format=json&utf8=
# Cornel_West
# https://en.wikipedia.org/w/api.php?action=query&titles=Cornel_West&prop=revisions&rvprop=content&format=json&utf8=
# Cornelius_Castoriadis
# https://en.wikipedia.org/w/api.php?action=query&titles=Cornelius_Castoriadis&prop=revisions&rvprop=content&format=json&utf8=
# Costas_Douzinas
# https://en.wikipedia.org/w/api.php?action=query&titles=Costas_Douzinas&prop=revisions&rvprop=content&format=json&utf8=
# Craig_Paterson
# https://en.wikipedia.org/w/api.php?action=query&titles=Craig_Paterson&prop=revisions&rvprop=content&format=json&utf8=
# Dag_Prawitz
# https://en.wikipedia.org/w/api.php?action=query&titles=Dag_Prawitz&prop=revisions&rvprop=content&format=json&utf8=
# Damon_Young
# https://en.wikipedia.org/w/api.php?action=query&titles=Damon_Young&prop=revisions&rvprop=content&format=json&utf8=
# Dana_Scott
# https://en.wikipedia.org/w/api.php?action=query&titles=Dana_Scott&prop=revisions&rvprop=content&format=json&utf8=
# Dana_Ward
# https://en.wikipedia.org/w/api.php?action=query&titles=Dana_Ward&prop=revisions&rvprop=content&format=json&utf8=
# Daniel_Brock
# https://en.wikipedia.org/w/api.php?action=query&titles=Daniel_Brock&prop=revisions&rvprop=content&format=json&utf8=
# Daniel_Gu%C3%A9rin
# https://en.wikipedia.org/w/api.php?action=query&titles=Daniel_Gu%C3%A9rin&prop=revisions&rvprop=content&format=json&utf8=
# Daniel_Wikler
# https://en.wikipedia.org/w/api.php?action=query&titles=Daniel_Wikler&prop=revisions&rvprop=content&format=json&utf8=
# David_Bohm
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Bohm&prop=revisions&rvprop=content&format=json&utf8=
# David_Chalmers
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Chalmers&prop=revisions&rvprop=content&format=json&utf8=
# David_Crocker
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Crocker&prop=revisions&rvprop=content&format=json&utf8=
# David_D._Friedman
# https://en.wikipedia.org/w/api.php?action=query&titles=David_D._Friedman&prop=revisions&rvprop=content&format=json&utf8=
# David_Friedrich_Strauss
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Friedrich_Strauss&prop=revisions&rvprop=content&format=json&utf8=
# David_Gauthier
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Gauthier&prop=revisions&rvprop=content&format=json&utf8=
# David_Hilbert
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Hilbert&prop=revisions&rvprop=content&format=json&utf8=
# David_Hume
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Hume&prop=revisions&rvprop=content&format=json&utf8=
# David_K._Lewis
# https://en.wikipedia.org/w/api.php?action=query&titles=David_K._Lewis&prop=revisions&rvprop=content&format=json&utf8=
# David_Kaplan_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kaplan_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# David_Kellogg_Lewis
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kellogg_Lewis&prop=revisions&rvprop=content&format=json&utf8=
# David_Kolb
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Kolb&prop=revisions&rvprop=content&format=json&utf8=
# David_Korten
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Korten&prop=revisions&rvprop=content&format=json&utf8=
# David_L._Norton
# https://en.wikipedia.org/w/api.php?action=query&titles=David_L._Norton&prop=revisions&rvprop=content&format=json&utf8=
# David_Lewis_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Lewis_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# David_Makinson
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Makinson&prop=revisions&rvprop=content&format=json&utf8=
# David_Malet_Armstrong
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Malet_Armstrong&prop=revisions&rvprop=content&format=json&utf8=
# David_Miller_%28political_theorist%29
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Miller_%28political_theorist%29&prop=revisions&rvprop=content&format=json&utf8=
# David_Pearce_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Pearce_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# David_Prychitko
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Prychitko&prop=revisions&rvprop=content&format=json&utf8=
# David_Schmidtz
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Schmidtz&prop=revisions&rvprop=content&format=json&utf8=
# David_Sosa
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Sosa&prop=revisions&rvprop=content&format=json&utf8=
# David_Wiggins
# https://en.wikipedia.org/w/api.php?action=query&titles=David_Wiggins&prop=revisions&rvprop=content&format=json&utf8=
# Dean_Zimmerman
# https://en.wikipedia.org/w/api.php?action=query&titles=Dean_Zimmerman&prop=revisions&rvprop=content&format=json&utf8=
# Democritus
# https://en.wikipedia.org/w/api.php?action=query&titles=Democritus&prop=revisions&rvprop=content&format=json&utf8=
# Derek_Parfit
# https://en.wikipedia.org/w/api.php?action=query&titles=Derek_Parfit&prop=revisions&rvprop=content&format=json&utf8=
# Dharmakirti
# https://en.wikipedia.org/w/api.php?action=query&titles=Dharmakirti&prop=revisions&rvprop=content&format=json&utf8=
# Dick_de_Jongh
# https://en.wikipedia.org/w/api.php?action=query&titles=Dick_de_Jongh&prop=revisions&rvprop=content&format=json&utf8=
# Dietrich_Bonhoeffer
# https://en.wikipedia.org/w/api.php?action=query&titles=Dietrich_Bonhoeffer&prop=revisions&rvprop=content&format=json&utf8=
# Dign%C4%81ga
# https://en.wikipedia.org/w/api.php?action=query&titles=Dign%C4%81ga&prop=revisions&rvprop=content&format=json&utf8=
# Dimiter_Skordev
# https://en.wikipedia.org/w/api.php?action=query&titles=Dimiter_Skordev&prop=revisions&rvprop=content&format=json&utf8=
# Dimitris_Dimitrakos
# https://en.wikipedia.org/w/api.php?action=query&titles=Dimitris_Dimitrakos&prop=revisions&rvprop=content&format=json&utf8=
# Diodorus_Cronus
# https://en.wikipedia.org/w/api.php?action=query&titles=Diodorus_Cronus&prop=revisions&rvprop=content&format=json&utf8=
# Dirk_van_Dalen
# https://en.wikipedia.org/w/api.php?action=query&titles=Dirk_van_Dalen&prop=revisions&rvprop=content&format=json&utf8=
# Disciples_of_Confucius
# https://en.wikipedia.org/w/api.php?action=query&titles=Disciples_of_Confucius&prop=revisions&rvprop=content&format=json&utf8=
# Donald_A._Martin
# https://en.wikipedia.org/w/api.php?action=query&titles=Donald_A._Martin&prop=revisions&rvprop=content&format=json&utf8=
# Donella_Meadows
# https://en.wikipedia.org/w/api.php?action=query&titles=Donella_Meadows&prop=revisions&rvprop=content&format=json&utf8=
# Dong_Zhongshu
# https://en.wikipedia.org/w/api.php?action=query&titles=Dong_Zhongshu&prop=revisions&rvprop=content&format=json&utf8=
# Donna_Haraway
# https://en.wikipedia.org/w/api.php?action=query&titles=Donna_Haraway&prop=revisions&rvprop=content&format=json&utf8=
# Dov_Gabbay
# https://en.wikipedia.org/w/api.php?action=query&titles=Dov_Gabbay&prop=revisions&rvprop=content&format=json&utf8=
# Dugald_Macpherson
# https://en.wikipedia.org/w/api.php?action=query&titles=Dugald_Macpherson&prop=revisions&rvprop=content&format=json&utf8=
# Dugald_Stewart
# https://en.wikipedia.org/w/api.php?action=query&titles=Dugald_Stewart&prop=revisions&rvprop=content&format=json&utf8=
# Duncan_Kennedy_%28legal_philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Duncan_Kennedy_%28legal_philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Duns_Scotus
# https://en.wikipedia.org/w/api.php?action=query&titles=Duns_Scotus&prop=revisions&rvprop=content&format=json&utf8=
# Edgar_Allan_Poe
# https://en.wikipedia.org/w/api.php?action=query&titles=Edgar_Allan_Poe&prop=revisions&rvprop=content&format=json&utf8=
# Edgar_Morin
# https://en.wikipedia.org/w/api.php?action=query&titles=Edgar_Morin&prop=revisions&rvprop=content&format=json&utf8=
# Edmund_Gettier
# https://en.wikipedia.org/w/api.php?action=query&titles=Edmund_Gettier&prop=revisions&rvprop=content&format=json&utf8=
# Edmund_Gurney
# https://en.wikipedia.org/w/api.php?action=query&titles=Edmund_Gurney&prop=revisions&rvprop=content&format=json&utf8=
# Eduard_Hanslick
# https://en.wikipedia.org/w/api.php?action=query&titles=Eduard_Hanslick&prop=revisions&rvprop=content&format=json&utf8=
# Edward_Hundert
# https://en.wikipedia.org/w/api.php?action=query&titles=Edward_Hundert&prop=revisions&rvprop=content&format=json&utf8=
# Edward_Nelson
# https://en.wikipedia.org/w/api.php?action=query&titles=Edward_Nelson&prop=revisions&rvprop=content&format=json&utf8=
# Edward_Said
# https://en.wikipedia.org/w/api.php?action=query&titles=Edward_Said&prop=revisions&rvprop=content&format=json&utf8=
# Ehud_Hrushovski
# https://en.wikipedia.org/w/api.php?action=query&titles=Ehud_Hrushovski&prop=revisions&rvprop=content&format=json&utf8=
# Eli_Siegel
# https://en.wikipedia.org/w/api.php?action=query&titles=Eli_Siegel&prop=revisions&rvprop=content&format=json&utf8=
# Elizabeth_Harman_%28disambiguation%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Elizabeth_Harman_%28disambiguation%29&prop=revisions&rvprop=content&format=json&utf8=
# Elliot_N._Dorff
# https://en.wikipedia.org/w/api.php?action=query&titles=Elliot_N._Dorff&prop=revisions&rvprop=content&format=json&utf8=
# Emil_Leon_Post
# https://en.wikipedia.org/w/api.php?action=query&titles=Emil_Leon_Post&prop=revisions&rvprop=content&format=json&utf8=
# Emma_Goldman
# https://en.wikipedia.org/w/api.php?action=query&titles=Emma_Goldman&prop=revisions&rvprop=content&format=json&utf8=
# Emma_Rush
# https://en.wikipedia.org/w/api.php?action=query&titles=Emma_Rush&prop=revisions&rvprop=content&format=json&utf8=
# Emmanuel_Levinas
# https://en.wikipedia.org/w/api.php?action=query&titles=Emmanuel_Levinas&prop=revisions&rvprop=content&format=json&utf8=
# Enrique_Dussel
# https://en.wikipedia.org/w/api.php?action=query&titles=Enrique_Dussel&prop=revisions&rvprop=content&format=json&utf8=
# Epicurus
# https://en.wikipedia.org/w/api.php?action=query&titles=Epicurus&prop=revisions&rvprop=content&format=json&utf8=
# Eric_Voegelin
# https://en.wikipedia.org/w/api.php?action=query&titles=Eric_Voegelin&prop=revisions&rvprop=content&format=json&utf8=
# Erich_Fromm
# https://en.wikipedia.org/w/api.php?action=query&titles=Erich_Fromm&prop=revisions&rvprop=content&format=json&utf8=
# Erich_Heller
# https://en.wikipedia.org/w/api.php?action=query&titles=Erich_Heller&prop=revisions&rvprop=content&format=json&utf8=
# Ernest_Sosa
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernest_Sosa&prop=revisions&rvprop=content&format=json&utf8=
# Ernest_Wamba_dia_Wamba
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernest_Wamba_dia_Wamba&prop=revisions&rvprop=content&format=json&utf8=
# Ernst_Bloch
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_Bloch&prop=revisions&rvprop=content&format=json&utf8=
# Ernst_Schr%C3%B6der
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_Schr%C3%B6der&prop=revisions&rvprop=content&format=json&utf8=
# Ernst_Zermelo
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_Zermelo&prop=revisions&rvprop=content&format=json&utf8=
# Ernst_von_Glasersfeld
# https://en.wikipedia.org/w/api.php?action=query&titles=Ernst_von_Glasersfeld&prop=revisions&rvprop=content&format=json&utf8=
# Etienne_Gilson
# https://en.wikipedia.org/w/api.php?action=query&titles=Etienne_Gilson&prop=revisions&rvprop=content&format=json&utf8=
# Eugen_Rosenstock-Huessy
# https://en.wikipedia.org/w/api.php?action=query&titles=Eugen_Rosenstock-Huessy&prop=revisions&rvprop=content&format=json&utf8=
# Evert_Willem_Beth
# https://en.wikipedia.org/w/api.php?action=query&titles=Evert_Willem_Beth&prop=revisions&rvprop=content&format=json&utf8=
# Fatema_Mernissi
# https://en.wikipedia.org/w/api.php?action=query&titles=Fatema_Mernissi&prop=revisions&rvprop=content&format=json&utf8=
# Fazlur_Rahman
# https://en.wikipedia.org/w/api.php?action=query&titles=Fazlur_Rahman&prop=revisions&rvprop=content&format=json&utf8=
# Felix_Kaufmann
# https://en.wikipedia.org/w/api.php?action=query&titles=Felix_Kaufmann&prop=revisions&rvprop=content&format=json&utf8=
# Ferdinand_Gotthelf_Hand
# https://en.wikipedia.org/w/api.php?action=query&titles=Ferdinand_Gotthelf_Hand&prop=revisions&rvprop=content&format=json&utf8=
# Ferruccio_Busoni
# https://en.wikipedia.org/w/api.php?action=query&titles=Ferruccio_Busoni&prop=revisions&rvprop=content&format=json&utf8=
# Francesco_D%27Andrea
# https://en.wikipedia.org/w/api.php?action=query&titles=Francesco_D%27Andrea&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Bacon
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Bacon&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Ernest_Jackson
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Ernest_Jackson&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Fukuyama
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Fukuyama&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Hutcheson_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Hutcheson_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Jeffrey
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Jeffrey&prop=revisions&rvprop=content&format=json&utf8=
# Francis_Parker_Yockey
# https://en.wikipedia.org/w/api.php?action=query&titles=Francis_Parker_Yockey&prop=revisions&rvprop=content&format=json&utf8=
# Francisco_de_Vitoria
# https://en.wikipedia.org/w/api.php?action=query&titles=Francisco_de_Vitoria&prop=revisions&rvprop=content&format=json&utf8=
# Franco_Burgersdijk
# https://en.wikipedia.org/w/api.php?action=query&titles=Franco_Burgersdijk&prop=revisions&rvprop=content&format=json&utf8=
# Frank_Herbert
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Herbert&prop=revisions&rvprop=content&format=json&utf8=
# Frank_Meyer_%28political_philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Meyer_%28political_philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Frank_Plumpton_Ramsey
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Plumpton_Ramsey&prop=revisions&rvprop=content&format=json&utf8=
# Frank_Schmalleger
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Schmalleger&prop=revisions&rvprop=content&format=json&utf8=
# Frank_Sibley_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Frank_Sibley_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Franz_Xaver_von_Baader
# https://en.wikipedia.org/w/api.php?action=query&titles=Franz_Xaver_von_Baader&prop=revisions&rvprop=content&format=json&utf8=
# Fran%C3%A7ois_Hemsterhuis
# https://en.wikipedia.org/w/api.php?action=query&titles=Fran%C3%A7ois_Hemsterhuis&prop=revisions&rvprop=content&format=json&utf8=
# Fred_Dretske
# https://en.wikipedia.org/w/api.php?action=query&titles=Fred_Dretske&prop=revisions&rvprop=content&format=json&utf8=
# Fred_Poch%C3%A9
# https://en.wikipedia.org/w/api.php?action=query&titles=Fred_Poch%C3%A9&prop=revisions&rvprop=content&format=json&utf8=
# Frederick_Rowbottom
# https://en.wikipedia.org/w/api.php?action=query&titles=Frederick_Rowbottom&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_A._Hayek
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_A._Hayek&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Adolf_Trendelenburg
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Adolf_Trendelenburg&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Daniel_Ernst_Schleiermacher
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Daniel_Ernst_Schleiermacher&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Eduard_Beneke
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Eduard_Beneke&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Hayek
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Hayek&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Nietzsche
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Nietzsche&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Schiller
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Schiller&prop=revisions&rvprop=content&format=json&utf8=
# Friedrich_Wilhelm_Joseph_von_Schelling
# https://en.wikipedia.org/w/api.php?action=query&titles=Friedrich_Wilhelm_Joseph_von_Schelling&prop=revisions&rvprop=content&format=json&utf8=
# Frithjof_Schuon
# https://en.wikipedia.org/w/api.php?action=query&titles=Frithjof_Schuon&prop=revisions&rvprop=content&format=json&utf8=
# Fujiwara_Seika
# https://en.wikipedia.org/w/api.php?action=query&titles=Fujiwara_Seika&prop=revisions&rvprop=content&format=json&utf8=
# Fyodor_Shcherbatskoy
# https://en.wikipedia.org/w/api.php?action=query&titles=Fyodor_Shcherbatskoy&prop=revisions&rvprop=content&format=json&utf8=
# F%C3%A9lix_Guattari
# https://en.wikipedia.org/w/api.php?action=query&titles=F%C3%A9lix_Guattari&prop=revisions&rvprop=content&format=json&utf8=
# G._E._M._Anscombe
# https://en.wikipedia.org/w/api.php?action=query&titles=G._E._M._Anscombe&prop=revisions&rvprop=content&format=json&utf8=
# G._E._Moore
# https://en.wikipedia.org/w/api.php?action=query&titles=G._E._Moore&prop=revisions&rvprop=content&format=json&utf8=
# G.W.F._Hegel
# https://en.wikipedia.org/w/api.php?action=query&titles=G.W.F._Hegel&prop=revisions&rvprop=content&format=json&utf8=
# Gabriele_Taylor
# https://en.wikipedia.org/w/api.php?action=query&titles=Gabriele_Taylor&prop=revisions&rvprop=content&format=json&utf8=
# Gaisi_Takeuti
# https://en.wikipedia.org/w/api.php?action=query&titles=Gaisi_Takeuti&prop=revisions&rvprop=content&format=json&utf8=
# Galileo_Galilei
# https://en.wikipedia.org/w/api.php?action=query&titles=Galileo_Galilei&prop=revisions&rvprop=content&format=json&utf8=
# Garlandus_Compotista
# https://en.wikipedia.org/w/api.php?action=query&titles=Garlandus_Compotista&prop=revisions&rvprop=content&format=json&utf8=
# Garry_Hagberg
# https://en.wikipedia.org/w/api.php?action=query&titles=Garry_Hagberg&prop=revisions&rvprop=content&format=json&utf8=
# Gary_Chartier
# https://en.wikipedia.org/w/api.php?action=query&titles=Gary_Chartier&prop=revisions&rvprop=content&format=json&utf8=
# Gary_R._Mar
# https://en.wikipedia.org/w/api.php?action=query&titles=Gary_R._Mar&prop=revisions&rvprop=content&format=json&utf8=
# Gautama_Buddha
# https://en.wikipedia.org/w/api.php?action=query&titles=Gautama_Buddha&prop=revisions&rvprop=content&format=json&utf8=
# Gene_Callahan_%28economist%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Gene_Callahan_%28economist%29&prop=revisions&rvprop=content&format=json&utf8=
# Geoffrey_Sayre-McCord
# https://en.wikipedia.org/w/api.php?action=query&titles=Geoffrey_Sayre-McCord&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Anton_Friedrich_Ast
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Anton_Friedrich_Ast&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Brandes
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Brandes&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Cantor
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Cantor&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Henrik_von_Wright
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Henrik_von_Wright&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Jellinek
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Jellinek&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Kreisel
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Kreisel&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Mehlis
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Mehlis&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Simmel
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Simmel&prop=revisions&rvprop=content&format=json&utf8=
# Georg_W._F._Hegel
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_W._F._Hegel&prop=revisions&rvprop=content&format=json&utf8=
# Georg_Wilhelm_Friedrich_Hegel
# https://en.wikipedia.org/w/api.php?action=query&titles=Georg_Wilhelm_Friedrich_Hegel&prop=revisions&rvprop=content&format=json&utf8=
# George_Berkeley
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Berkeley&prop=revisions&rvprop=content&format=json&utf8=
# George_Birkhoff
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Birkhoff&prop=revisions&rvprop=content&format=json&utf8=
# George_Boole
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Boole&prop=revisions&rvprop=content&format=json&utf8=
# George_Boolos
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Boolos&prop=revisions&rvprop=content&format=json&utf8=
# George_Croom_Robertson
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Croom_Robertson&prop=revisions&rvprop=content&format=json&utf8=
# George_Edward_Moore
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Edward_Moore&prop=revisions&rvprop=content&format=json&utf8=
# George_Holmes_Howison
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Holmes_Howison&prop=revisions&rvprop=content&format=json&utf8=
# George_Kateb
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Kateb&prop=revisions&rvprop=content&format=json&utf8=
# George_Ohsawa
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Ohsawa&prop=revisions&rvprop=content&format=json&utf8=
# George_Pappas
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Pappas&prop=revisions&rvprop=content&format=json&utf8=
# George_Santayana
# https://en.wikipedia.org/w/api.php?action=query&titles=George_Santayana&prop=revisions&rvprop=content&format=json&utf8=
# Georges_Bataille
# https://en.wikipedia.org/w/api.php?action=query&titles=Georges_Bataille&prop=revisions&rvprop=content&format=json&utf8=
# Gerald_Cohen
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerald_Cohen&prop=revisions&rvprop=content&format=json&utf8=
# Gerald_Dworkin
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerald_Dworkin&prop=revisions&rvprop=content&format=json&utf8=
# Gerald_Sacks
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerald_Sacks&prop=revisions&rvprop=content&format=json&utf8=
# Gerhard_Gentzen
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerhard_Gentzen&prop=revisions&rvprop=content&format=json&utf8=
# Gerhard_Vollmer
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerhard_Vollmer&prop=revisions&rvprop=content&format=json&utf8=
# Gerrard_Winstanley
# https://en.wikipedia.org/w/api.php?action=query&titles=Gerrard_Winstanley&prop=revisions&rvprop=content&format=json&utf8=
# Ghazali
# https://en.wikipedia.org/w/api.php?action=query&titles=Ghazali&prop=revisions&rvprop=content&format=json&utf8=
# Giacomo_Marramao
# https://en.wikipedia.org/w/api.php?action=query&titles=Giacomo_Marramao&prop=revisions&rvprop=content&format=json&utf8=
# Giambattista_Vico
# https://en.wikipedia.org/w/api.php?action=query&titles=Giambattista_Vico&prop=revisions&rvprop=content&format=json&utf8=
# Gianfranco_Sanguinetti
# https://en.wikipedia.org/w/api.php?action=query&titles=Gianfranco_Sanguinetti&prop=revisions&rvprop=content&format=json&utf8=
# Giannina_Braschi
# https://en.wikipedia.org/w/api.php?action=query&titles=Giannina_Braschi&prop=revisions&rvprop=content&format=json&utf8=
# Gilbert_Harman
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilbert_Harman&prop=revisions&rvprop=content&format=json&utf8=
# Gilbert_Simondon
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilbert_Simondon&prop=revisions&rvprop=content&format=json&utf8=
# Gilbert_de_la_Porr%C3%A9e
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilbert_de_la_Porr%C3%A9e&prop=revisions&rvprop=content&format=json&utf8=
# Gilles_Deleuze
# https://en.wikipedia.org/w/api.php?action=query&titles=Gilles_Deleuze&prop=revisions&rvprop=content&format=json&utf8=
# Giorgi_Japaridze
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgi_Japaridze&prop=revisions&rvprop=content&format=json&utf8=
# Giorgio_Agamben
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgio_Agamben&prop=revisions&rvprop=content&format=json&utf8=
# Giorgio_Del_Vecchio
# https://en.wikipedia.org/w/api.php?action=query&titles=Giorgio_Del_Vecchio&prop=revisions&rvprop=content&format=json&utf8=
# Giovanni_Battista_Scaramelli
# https://en.wikipedia.org/w/api.php?action=query&titles=Giovanni_Battista_Scaramelli&prop=revisions&rvprop=content&format=json&utf8=
# Giovanni_Girolamo_Saccheri
# https://en.wikipedia.org/w/api.php?action=query&titles=Giovanni_Girolamo_Saccheri&prop=revisions&rvprop=content&format=json&utf8=
# Giuseppe_Peano
# https://en.wikipedia.org/w/api.php?action=query&titles=Giuseppe_Peano&prop=revisions&rvprop=content&format=json&utf8=
# Glenn_McGee
# https://en.wikipedia.org/w/api.php?action=query&titles=Glenn_McGee&prop=revisions&rvprop=content&format=json&utf8=
# Gottfried_Leibniz
# https://en.wikipedia.org/w/api.php?action=query&titles=Gottfried_Leibniz&prop=revisions&rvprop=content&format=json&utf8=
# Gotthold_Ephraim_Lessing
# https://en.wikipedia.org/w/api.php?action=query&titles=Gotthold_Ephraim_Lessing&prop=revisions&rvprop=content&format=json&utf8=
# Gottlob_Frege
# https://en.wikipedia.org/w/api.php?action=query&titles=Gottlob_Frege&prop=revisions&rvprop=content&format=json&utf8=
# Graeme_Forbes
# https://en.wikipedia.org/w/api.php?action=query&titles=Graeme_Forbes&prop=revisions&rvprop=content&format=json&utf8=
# Graham_Priest
# https://en.wikipedia.org/w/api.php?action=query&titles=Graham_Priest&prop=revisions&rvprop=content&format=json&utf8=
# Gregory_Chaitin
# https://en.wikipedia.org/w/api.php?action=query&titles=Gregory_Chaitin&prop=revisions&rvprop=content&format=json&utf8=
# Gregory_Currie
# https://en.wikipedia.org/w/api.php?action=query&titles=Gregory_Currie&prop=revisions&rvprop=content&format=json&utf8=
# Grigori_Mints
# https://en.wikipedia.org/w/api.php?action=query&titles=Grigori_Mints&prop=revisions&rvprop=content&format=json&utf8=
# Gualtiero_Piccinini
# https://en.wikipedia.org/w/api.php?action=query&titles=Gualtiero_Piccinini&prop=revisions&rvprop=content&format=json&utf8=
# Gustave_de_Molinari
# https://en.wikipedia.org/w/api.php?action=query&titles=Gustave_de_Molinari&prop=revisions&rvprop=content&format=json&utf8=
# Guy_Aldred
# https://en.wikipedia.org/w/api.php?action=query&titles=Guy_Aldred&prop=revisions&rvprop=content&format=json&utf8=
# Guy_Debord
# https://en.wikipedia.org/w/api.php?action=query&titles=Guy_Debord&prop=revisions&rvprop=content&format=json&utf8=
# Guy_Sircello
# https://en.wikipedia.org/w/api.php?action=query&titles=Guy_Sircello&prop=revisions&rvprop=content&format=json&utf8=
# Gy%C3%B6rgy_Luk%C3%A1cs
# https://en.wikipedia.org/w/api.php?action=query&titles=Gy%C3%B6rgy_Luk%C3%A1cs&prop=revisions&rvprop=content&format=json&utf8=
# H._B._Acton
# https://en.wikipedia.org/w/api.php?action=query&titles=H._B._Acton&prop=revisions&rvprop=content&format=json&utf8=
# H._L._A._Hart
# https://en.wikipedia.org/w/api.php?action=query&titles=H._L._A._Hart&prop=revisions&rvprop=content&format=json&utf8=
# H._Richard_Niebuhr
# https://en.wikipedia.org/w/api.php?action=query&titles=H._Richard_Niebuhr&prop=revisions&rvprop=content&format=json&utf8=
# Hammurabi
# https://en.wikipedia.org/w/api.php?action=query&titles=Hammurabi&prop=revisions&rvprop=content&format=json&utf8=
# Han_Fei
# https://en.wikipedia.org/w/api.php?action=query&titles=Han_Fei&prop=revisions&rvprop=content&format=json&utf8=
# Han_Ryner
# ...
# Mohandas_Gandhi
# https://en.wikipedia.org/w/api.php?action=query&titles=Mohandas_Gandhi&prop=revisions&rvprop=content&format=json&utf8=
# Mohandas_Karamchand_Gandhi
# https://en.wikipedia.org/w/api.php?action=query&titles=Mohandas_Karamchand_Gandhi&prop=revisions&rvprop=content&format=json&utf8=
# Moj%C5%BCesz_Presburger
# https://en.wikipedia.org/w/api.php?action=query&titles=Moj%C5%BCesz_Presburger&prop=revisions&rvprop=content&format=json&utf8=
# Monarchomachs
# https://en.wikipedia.org/w/api.php?action=query&titles=Monarchomachs&prop=revisions&rvprop=content&format=json&utf8=
# Monroe_Beardsley
# https://en.wikipedia.org/w/api.php?action=query&titles=Monroe_Beardsley&prop=revisions&rvprop=content&format=json&utf8=
# Montesquieu
# https://en.wikipedia.org/w/api.php?action=query&titles=Montesquieu&prop=revisions&rvprop=content&format=json&utf8=
# Moritz_Schlick
# https://en.wikipedia.org/w/api.php?action=query&titles=Moritz_Schlick&prop=revisions&rvprop=content&format=json&utf8=
# Morris_Weitz
# https://en.wikipedia.org/w/api.php?action=query&titles=Morris_Weitz&prop=revisions&rvprop=content&format=json&utf8=
# Mortimer_Adler
# https://en.wikipedia.org/w/api.php?action=query&titles=Mortimer_Adler&prop=revisions&rvprop=content&format=json&utf8=
# Moses
# https://en.wikipedia.org/w/api.php?action=query&titles=Moses&prop=revisions&rvprop=content&format=json&utf8=
# Moses_Sch%C3%B6nfinkel
# https://en.wikipedia.org/w/api.php?action=query&titles=Moses_Sch%C3%B6nfinkel&prop=revisions&rvprop=content&format=json&utf8=
# Moshe_Chaim_Luzzatto
# https://en.wikipedia.org/w/api.php?action=query&titles=Moshe_Chaim_Luzzatto&prop=revisions&rvprop=content&format=json&utf8=
# Moshe_Y._Vardi
# https://en.wikipedia.org/w/api.php?action=query&titles=Moshe_Y._Vardi&prop=revisions&rvprop=content&format=json&utf8=
# Mozi
# https://en.wikipedia.org/w/api.php?action=query&titles=Mozi&prop=revisions&rvprop=content&format=json&utf8=
# Muhammad
# https://en.wikipedia.org/w/api.php?action=query&titles=Muhammad&prop=revisions&rvprop=content&format=json&utf8=
# Muhammad_Asad
# https://en.wikipedia.org/w/api.php?action=query&titles=Muhammad_Asad&prop=revisions&rvprop=content&format=json&utf8=
# Muhammad_Iqbal
# https://en.wikipedia.org/w/api.php?action=query&titles=Muhammad_Iqbal&prop=revisions&rvprop=content&format=json&utf8=
# Murray_Bookchin
# https://en.wikipedia.org/w/api.php?action=query&titles=Murray_Bookchin&prop=revisions&rvprop=content&format=json&utf8=
# Murray_Rothbard
# https://en.wikipedia.org/w/api.php?action=query&titles=Murray_Rothbard&prop=revisions&rvprop=content&format=json&utf8=
# Nader_El-Bizri
# https://en.wikipedia.org/w/api.php?action=query&titles=Nader_El-Bizri&prop=revisions&rvprop=content&format=json&utf8=
# Nancy_Cartwright_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Nancy_Cartwright_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Nassim_Nicholas_Taleb
# https://en.wikipedia.org/w/api.php?action=query&titles=Nassim_Nicholas_Taleb&prop=revisions&rvprop=content&format=json&utf8=
# Nathan_Salmon
# https://en.wikipedia.org/w/api.php?action=query&titles=Nathan_Salmon&prop=revisions&rvprop=content&format=json&utf8=
# Nayef_Al-Rodhan
# https://en.wikipedia.org/w/api.php?action=query&titles=Nayef_Al-Rodhan&prop=revisions&rvprop=content&format=json&utf8=
# Nelson_Goodman
# https://en.wikipedia.org/w/api.php?action=query&titles=Nelson_Goodman&prop=revisions&rvprop=content&format=json&utf8=
# Nestor_Makhno
# https://en.wikipedia.org/w/api.php?action=query&titles=Nestor_Makhno&prop=revisions&rvprop=content&format=json&utf8=
# Newton_da_Costa
# https://en.wikipedia.org/w/api.php?action=query&titles=Newton_da_Costa&prop=revisions&rvprop=content&format=json&utf8=
# Niccol%C3%B2_Machiavelli
# https://en.wikipedia.org/w/api.php?action=query&titles=Niccol%C3%B2_Machiavelli&prop=revisions&rvprop=content&format=json&utf8=
# Nick_Bostrom
# https://en.wikipedia.org/w/api.php?action=query&titles=Nick_Bostrom&prop=revisions&rvprop=content&format=json&utf8=
# Nicolai_A._Vasiliev
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolai_A._Vasiliev&prop=revisions&rvprop=content&format=json&utf8=
# Nicolai_Hartmann
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolai_Hartmann&prop=revisions&rvprop=content&format=json&utf8=
# Nicolas_Bourbaki
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolas_Bourbaki&prop=revisions&rvprop=content&format=json&utf8=
# Nicolas_Malebranche
# https://en.wikipedia.org/w/api.php?action=query&titles=Nicolas_Malebranche&prop=revisions&rvprop=content&format=json&utf8=
# Nigel_Warburton
# https://en.wikipedia.org/w/api.php?action=query&titles=Nigel_Warburton&prop=revisions&rvprop=content&format=json&utf8=
# Niklas_Luhmann
# https://en.wikipedia.org/w/api.php?action=query&titles=Niklas_Luhmann&prop=revisions&rvprop=content&format=json&utf8=
# Noam_Chomsky
# https://en.wikipedia.org/w/api.php?action=query&titles=Noam_Chomsky&prop=revisions&rvprop=content&format=json&utf8=
# Nomy_Arpaly
# https://en.wikipedia.org/w/api.php?action=query&titles=Nomy_Arpaly&prop=revisions&rvprop=content&format=json&utf8=
# Norbert_Bolz
# https://en.wikipedia.org/w/api.php?action=query&titles=Norbert_Bolz&prop=revisions&rvprop=content&format=json&utf8=
# Norbert_Leser
# https://en.wikipedia.org/w/api.php?action=query&titles=Norbert_Leser&prop=revisions&rvprop=content&format=json&utf8=
# Norman_Daniels
# https://en.wikipedia.org/w/api.php?action=query&titles=Norman_Daniels&prop=revisions&rvprop=content&format=json&utf8=
# Norman_Malcolm
# https://en.wikipedia.org/w/api.php?action=query&titles=Norman_Malcolm&prop=revisions&rvprop=content&format=json&utf8=
# Nosson_Tzvi_Finkel_%28Slabodka%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Nosson_Tzvi_Finkel_%28Slabodka%29&prop=revisions&rvprop=content&format=json&utf8=
# Nuel_Belnap
# https://en.wikipedia.org/w/api.php?action=query&titles=Nuel_Belnap&prop=revisions&rvprop=content&format=json&utf8=
# Ny%C4%81ya_S%C5%ABtras
# https://en.wikipedia.org/w/api.php?action=query&titles=Ny%C4%81ya_S%C5%ABtras&prop=revisions&rvprop=content&format=json&utf8=
# Octave_Mirbeau
# https://en.wikipedia.org/w/api.php?action=query&titles=Octave_Mirbeau&prop=revisions&rvprop=content&format=json&utf8=
# Ogy%C5%AB_Sorai
# https://en.wikipedia.org/w/api.php?action=query&titles=Ogy%C5%AB_Sorai&prop=revisions&rvprop=content&format=json&utf8=
# Oliver_Wendell_Holmes%2C_Jr.
# https://en.wikipedia.org/w/api.php?action=query&titles=Oliver_Wendell_Holmes%2C_Jr.&prop=revisions&rvprop=content&format=json&utf8=
# Onora_O%27Neill%2C_Baroness_O%27Neill_of_Bengarve
# https://en.wikipedia.org/w/api.php?action=query&titles=Onora_O%27Neill%2C_Baroness_O%27Neill_of_Bengarve&prop=revisions&rvprop=content&format=json&utf8=
# Oscar_Wilde
# https://en.wikipedia.org/w/api.php?action=query&titles=Oscar_Wilde&prop=revisions&rvprop=content&format=json&utf8=
# Oskar_Negt
# https://en.wikipedia.org/w/api.php?action=query&titles=Oskar_Negt&prop=revisions&rvprop=content&format=json&utf8=
# Oswald_von_Nell-Breuning
# https://en.wikipedia.org/w/api.php?action=query&titles=Oswald_von_Nell-Breuning&prop=revisions&rvprop=content&format=json&utf8=
# Otto_Weininger
# https://en.wikipedia.org/w/api.php?action=query&titles=Otto_Weininger&prop=revisions&rvprop=content&format=json&utf8=
# Owen_Flanagan
# https://en.wikipedia.org/w/api.php?action=query&titles=Owen_Flanagan&prop=revisions&rvprop=content&format=json&utf8=
# P._F._Strawson
# https://en.wikipedia.org/w/api.php?action=query&titles=P._F._Strawson&prop=revisions&rvprop=content&format=json&utf8=
# Paolo_Virno
# https://en.wikipedia.org/w/api.php?action=query&titles=Paolo_Virno&prop=revisions&rvprop=content&format=json&utf8=
# Paolo_da_Pergola
# https://en.wikipedia.org/w/api.php?action=query&titles=Paolo_da_Pergola&prop=revisions&rvprop=content&format=json&utf8=
# Parmenides
# https://en.wikipedia.org/w/api.php?action=query&titles=Parmenides&prop=revisions&rvprop=content&format=json&utf8=
# Partha_Dasgupta
# https://en.wikipedia.org/w/api.php?action=query&titles=Partha_Dasgupta&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Benacerraf
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Benacerraf&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Bernays
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Bernays&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Cohen_%28mathematician%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Cohen_%28mathematician%29&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Grice
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Grice&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Hawken
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Hawken&prop=revisions&rvprop=content&format=json&utf8=
# Paul_H%C3%A4berlin
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_H%C3%A4berlin&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Janet
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Janet&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Lorenzen
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Lorenzen&prop=revisions&rvprop=content&format=json&utf8=
# Paul_R._Patton
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_R._Patton&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Tillich
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Tillich&prop=revisions&rvprop=content&format=json&utf8=
# Paul_Virilio
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_Virilio&prop=revisions&rvprop=content&format=json&utf8=
# Paul_of_Venice
# https://en.wikipedia.org/w/api.php?action=query&titles=Paul_of_Venice&prop=revisions&rvprop=content&format=json&utf8=
# Pavel_Tich%C3%BD
# https://en.wikipedia.org/w/api.php?action=query&titles=Pavel_Tich%C3%BD&prop=revisions&rvprop=content&format=json&utf8=
# Pekka_Himanen
# https://en.wikipedia.org/w/api.php?action=query&titles=Pekka_Himanen&prop=revisions&rvprop=content&format=json&utf8=
# Penelope_Maddy
# https://en.wikipedia.org/w/api.php?action=query&titles=Penelope_Maddy&prop=revisions&rvprop=content&format=json&utf8=
# Per_Bauhn
# https://en.wikipedia.org/w/api.php?action=query&titles=Per_Bauhn&prop=revisions&rvprop=content&format=json&utf8=
# Per_Martin-L%C3%B6f
# https://en.wikipedia.org/w/api.php?action=query&titles=Per_Martin-L%C3%B6f&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Abelard
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Abelard&prop=revisions&rvprop=content&format=json&utf8=
# Peter_B._Andrews_%28mathematician%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_B._Andrews_%28mathematician%29&prop=revisions&rvprop=content&format=json&utf8=
# Peter_D._Klein
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_D._Klein&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Geach
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Geach&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Glassen
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Glassen&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Goldie
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Goldie&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Kivy
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Kivy&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Kropotkin
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Kropotkin&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Lamborn_Wilson
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Lamborn_Wilson&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Lipton
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Lipton&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Ludlow
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Ludlow&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Lunenfeld
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Lunenfeld&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Medawar
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Medawar&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Railton
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Railton&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Singer
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Singer&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Sloterdijk
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Sloterdijk&prop=revisions&rvprop=content&format=json&utf8=
# Peter_Unger
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_Unger&prop=revisions&rvprop=content&format=json&utf8=
# Peter_of_Spain_%28author%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_of_Spain_%28author%29&prop=revisions&rvprop=content&format=json&utf8=
# Peter_van_Inwagen
# https://en.wikipedia.org/w/api.php?action=query&titles=Peter_van_Inwagen&prop=revisions&rvprop=content&format=json&utf8=
# Petr_H%C3%A1jek
# https://en.wikipedia.org/w/api.php?action=query&titles=Petr_H%C3%A1jek&prop=revisions&rvprop=content&format=json&utf8=
# Petrus_Ramus
# https://en.wikipedia.org/w/api.php?action=query&titles=Petrus_Ramus&prop=revisions&rvprop=content&format=json&utf8=
# Phaleas_of_Chalcedon
# https://en.wikipedia.org/w/api.php?action=query&titles=Phaleas_of_Chalcedon&prop=revisions&rvprop=content&format=json&utf8=
# Philip_Doddridge
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Doddridge&prop=revisions&rvprop=content&format=json&utf8=
# Philip_Jourdain
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Jourdain&prop=revisions&rvprop=content&format=json&utf8=
# Philip_Mazzei
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Mazzei&prop=revisions&rvprop=content&format=json&utf8=
# Philip_Pettit
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Pettit&prop=revisions&rvprop=content&format=json&utf8=
# Philip_Wicksteed
# https://en.wikipedia.org/w/api.php?action=query&titles=Philip_Wicksteed&prop=revisions&rvprop=content&format=json&utf8=
# Philippa_Foot
# https://en.wikipedia.org/w/api.php?action=query&titles=Philippa_Foot&prop=revisions&rvprop=content&format=json&utf8=
# Philippe_Van_Parijs
# https://en.wikipedia.org/w/api.php?action=query&titles=Philippe_Van_Parijs&prop=revisions&rvprop=content&format=json&utf8=
# Phillip_H._Wiebe
# https://en.wikipedia.org/w/api.php?action=query&titles=Phillip_H._Wiebe&prop=revisions&rvprop=content&format=json&utf8=
# Philo
# https://en.wikipedia.org/w/api.php?action=query&titles=Philo&prop=revisions&rvprop=content&format=json&utf8=
# Philo_the_Dialectician
# https://en.wikipedia.org/w/api.php?action=query&titles=Philo_the_Dialectician&prop=revisions&rvprop=content&format=json&utf8=
# Piergiorgio_Odifreddi
# https://en.wikipedia.org/w/api.php?action=query&titles=Piergiorgio_Odifreddi&prop=revisions&rvprop=content&format=json&utf8=
# Pierre_Ab%C3%A9lard
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre_Ab%C3%A9lard&prop=revisions&rvprop=content&format=json&utf8=
# Pierre_Bourdieu
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre_Bourdieu&prop=revisions&rvprop=content&format=json&utf8=
# Pierre_Teilhard_de_Chardin
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre_Teilhard_de_Chardin&prop=revisions&rvprop=content&format=json&utf8=
# Pierre-Andr%C3%A9_Taguieff
# https://en.wikipedia.org/w/api.php?action=query&titles=Pierre-Andr%C3%A9_Taguieff&prop=revisions&rvprop=content&format=json&utf8=
# Plato
# https://en.wikipedia.org/w/api.php?action=query&titles=Plato&prop=revisions&rvprop=content&format=json&utf8=
# Plotinus
# https://en.wikipedia.org/w/api.php?action=query&titles=Plotinus&prop=revisions&rvprop=content&format=json&utf8=
# Porphyry_%28philosopher%29
# https://en.wikipedia.org/w/api.php?action=query&titles=Porphyry_%28philosopher%29&prop=revisions&rvprop=content&format=json&utf8=
# Proclus_Lycaeus
# https://en.wikipedia.org/w/api.php?action=query&titles=Proclus_Lycaeus&prop=revisions&rvprop=content&format=json&utf8=
# Prodicus
# https://en.wikipedia.org/w/api.php?action=query&titles=Prodicus&prop=revisions&rvprop=content&format=json&utf8=

# %% [markdown]
# Creating a graph using [Drawing - NetworkX documentation](https://networkx.github.io/documentation/networkx-1.10/reference/drawing.html)

# %%
import networkx as nx
import cPickle as pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# Reading the philosophers into graph 
data=nx.read_gpickle('phil_test.pkl')
phil_graph = nx.DiGraph(data) 


# Plotting the graph
nx.draw_spring(phil_graph,node_size=20,node_color='#B23AEE',scale=1)
plt.show()

# %% [markdown]
# **The reason for using a directed graph**

# %% [markdown]
# If one made the graph undirected, it would not be possible to see which of the two philosophers that linked to the other, one would just be able to see that there is some connection between the two.
#
# When using an undirected graph it is easy to find the most "attractive" philosopher, who will most likely have a higher *in-degree* than the rest of the philosophers.
#
# Using the concept of in and out-degree one can deduce something about the 'popularity'/significance of the work of the philosopher. A high *out-degree might* say something about where the philosopher at hand draws inspirati6on from, whereas the *in-degree* shows how inspirational that philosopher is to others.

# %% [markdown]
# **Number of nodes and links in the network**
#
# Using built-in functions for the directed graph to extract information about nodes and edges. Hopefully there will be $< 1115$ philosophers which is the number of philosophers in all lists where duplicates are unaccounted for.

# %%
node_list =  phil_graph.nodes()
edge_list = phil_graph.edges()

print "Number of edges: ", len(edge_list)
print "Number of nodes: ", len(node_list)

# %% [markdown]
# **Average and median degree**

# %%
# Average degree
avg_in = []  # in degrees
avg_out = [] # out degrees
degrees = phil_graph.degree()
sum_of_edges = sum(degrees.values())

for node in node_list:
    avg_in.append(phil_graph.in_degree(node))
    avg_out.append(phil_graph.out_degree(node))

print "Average degree in:  ", sum(avg_in)/len(node_list)
print "Average degree out: ", sum(avg_out)/len(node_list), "\n"

# Median degree
sort_in = sorted(avg_in)
sort_out = sorted(avg_out)

print "Median degree in:   ", sort_in[len(avg_in)/2]
print "Median degree out:  ", sort_out[len(avg_out)/2]

# %% [markdown]
# **Top 10 philosophers by in and out degree**

# %%
import collections

top_in = phil_graph.in_degree(node_list)
top_out = phil_graph.out_degree(node_list)

sorted_in = sorted(top_in.items(), key=operator.itemgetter(1),reverse=True)
sorted_out = sorted(top_in.items(), key=operator.itemgetter(1),reverse=True)

print "Philosophers with highest in-degree: \n", sorted_in[:10], "\n"
print "Philosophers with highest out-degree: \n", sorted_out[:10]

# %% [markdown]
# **Distribution of in and out degree, most common degree**

# %% [markdown]
# To plot the distribution of in and out degree xx..

# %%
import numpy as np

# Plot for in-degree
plt.hist(sorted_in.items())

# Plot for out-degree

# For readability
plt.grid(True)
plt.title("Gaussian Histogram, 10 bins")
plt.xlabel("Value")
plt.ylabel("Frequency")
# By default 10 bins is used.

# %% [markdown]
# **Plot of distribution on loglog scale**

# %% [markdown]
# **Description of distribution -- what do they look like?**

# %% [markdown]
# **Scatter-plot of in vs. out degree, comment on relation**

# %%
plt.scatter(node_list, edge_list)
