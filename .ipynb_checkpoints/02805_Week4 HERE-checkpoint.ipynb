# %% [markdown]
# # Week 4
# ## Notes

# %% [markdown]
# ### Regular Expressions in Python
# More about [regular expressions](https://developers.google.com/edu/python/regular-expressions)

# %%
import re # import regular expression module

# %%
# Basic
str = 'an example word:cat!!'
match = re.search(r'word:\w\w\w', str)
# If-statement after search() tests if it succeeded
if match:                      
  print 'found', match.group()
else:
  print 'did not find'
# Out:
# found word:cat

# %% [markdown]
# #### Findall

# %%
## Suppose we have a text with many email addresses
  str = 'purple alice@google.com, blah monkey bob@abc.com blah dishwasher'

  ## Here re.findall() returns a list of all the found email strings
  emails = re.findall(r'[\w\.-]+@[\w\.-]+', str) ## ['alice@google.com', 'bob@abc.com']
  for email in emails:
    # do something with each found email string
    print email

# %% [markdown]
# ## Exercises

# %% [markdown]
# **What are regular expressions?**
#
# Regular expressions uses pattern matching to find customized strings, substrings, repetitions etc. in texts and other material. There are many different ways to specify what you want.
#
# It is a sequence of characters that define a search pattern, mainly for use in pattern matching with strings, or string matching. It is the same as what is used when finding and replacing in Word etc.

# %% [markdown]
# **Regex to match 4 digit number**
#
# [Place to test regular expressions](https://regex101.com/)
#
# **An even better place to [test regex'es](https://regexr.com/)**

# %%
# Match exatcly 4 digits, no more no less.
# \d = digit char, \w = word char
# ''r' indicates a 'raw' string

# Fetching test content (for all examples here)
import urllib2
response = urllib2.urlopen('https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt')
html = response.read()

str = "hello54o oo  5688oo 63855"
# Matches 4 digits, possibly separated by whitespace
# Using lookbehind and lookahead
match = re.findall(r'(?<!\d)[0-9]{4}(?!\d)', html)
# match = re.search(r'^[0-9]{4}', str) 

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['1234', '9999']

# %% [markdown]
# **Provide an example of a regex to match words starting with "super".**
#
# Show that it works on the [test-text](https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt).

# %%
# Regex matching words STARTING with super
match = re.findall(r'super\w+', html)

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['superpolaroid', 'supertaxidermy', 'superbeer']

# %% [markdown]
# ### Regular expression pt. 2
# Getting the Wiki-links

# %%
# Show that you can extract the wiki-links from the test-text. 
match = re.findall(r'\[\[(?:[^|\]]*\|)?([^\]]+)\]\]', html)

if match:                      
  print 'Sequence matching pattern:', match
else:
  print 'No sequence matching pattern.'
# Out:
# Sequence matching pattern: ['drinking vinegar', 'gentrify', 'hashtag', 'Bicycle(two-wheeled type)', 'Pitchfork Magazine']

# %% [markdown]
# ## A Fun with Wikipedia

# %% [markdown]
# How to get the pages/markup through the Wiki-API

# %%
import urllib2
import json
response = urllib2.urlopen('https://en.wikipedia.org/wiki/List_of_aestheticians')
html = response.read()

# %%
baseurl    = "https://en.wikipedia.org/w/api.php?"
action     = "action=query"
title      = "titles="
content    = "prop=revisions&rvprop=content"
dataformat = "format=json"

# List of all Philosophers by core area
list_phil = ['List_of_aestheticians','List_of_epistemologists','List_of_ethicists','List_of_logicians','List_of_metaphysicians','List_of_social_and_political_philosophers']
query = []
# constructing query for getting all Philosopher data
for ii in range(0,len(list_phil)):
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+list_phil[ii],content,dataformat)
    print "Query for:", list_phil[ii]
    print (query)
# Out:
# Query for: List_of_aestheticians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_aestheticians&prop=revisions&rvprop=content&format=json&utf8=
# Query for: List_of_epistemologists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_epistemologists&prop=revisions&rvprop=content&format=json&utf8=
# Query for: List_of_ethicists
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_ethicists&prop=revisions&rvprop=content&format=json&utf8=
# Query for: List_of_logicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_logicians&prop=revisions&rvprop=content&format=json&utf8=
# Query for: List_of_metaphysicians
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_metaphysicians&prop=revisions&rvprop=content&format=json&utf8=
# Query for: List_of_social_and_political_philosophers
# https://en.wikipedia.org/w/api.php?action=query&titles=List_of_social_and_political_philosophers&prop=revisions&rvprop=content&format=json&utf8=

# %%
# Work on all collected data (saved in one file)
import io
import re
import numpy as np

f = io.open('./markup.txt','r',encoding='utf-8')
brac = re.findall(r'\*\s*\[\[([^\]|]+)\|?[^\]]*\]\]', f.read())

# %%
#Getting only unique values
unique_brac = np.unique(brac)

# Remove unwanted links 
trim_phil = [item for item in unique_brac if not item.lower().startswith('list of')]

# Printing the values
for link in trim_phil:
    print link
# Out:
# :nl:Martinus Dorpius
# A. J. Ayer
# Abraham Fraenkel
# Abraham Joshua Heschel
# Abraham Robinson
# Abraham ibn Daud
# Abul Kalam Azad
# Adam Müller
# Adam Smith
# Adolf Lindenbaum
# Adrian Johnston (philosopher)
# Ahmed Raza Khan
# Alain Badiou
# Alan Bundy
# Alan Carter (philosopher)
# Alan Gewirth
# Alan Ross Anderson
# Alan Ryan
# Alan Turing
# Alasdair MacIntyre
# Alasdair Urquhart
# Alastair Norcross
# Albert Camus
# Albert Schweitzer
# Albert of Saxony (philosopher)
# Alcuin
# Aldo Leopold
# Alexander Bain
# Alexander Campbell Fraser
# Alexander Esenin-Volpin
# Alexander Gerard
# Alexander Gottlieb Baumgarten
# Alexander S. Kechris
# Alexander Zinoviev
# Alexis de Tocqueville
# Alfred Horn
# Alfred North Whitehead
# Alfred Rosenberg
# Alfred Tarski
# Algernon Charles Swinburne
# Ali Shariati
# Alice Crary
# Alija Izetbegović
# Allan Gibbard
# Alon Ben-Meir
# Alonzo Church
# Alvin Goldman
# Alvin Plantinga
# Amartya Sen
# Ambrose
# Anandavardhana
# Anaximander
# Andrea Bonomì
# Andreas Linder
# Andrei Marga
# Andronicus of Rhodes
# Andrzej Mostowski
# Andrzej Tadeusz Kijowski
# André Malraux
# Anne Conway (philosopher)
# Anne Sjerp Troelstra
# Anthony de Jasay
# Antoine Garaby de La Luzerne
# Antonio Negri
# António Castanheira Neves
# Archon
# Arda Denkel
# Arend Heyting
# Aristotle
# Aristoxenus
# Armin Mohler
# Arnold Berleant
# W. Hugh Woodin
# W.K. Wimsatt
# W.V.O. Quine
# Walter Benjamin
# Walter Burley
# Walter Pater
# Walter Pitts
# Walter Terence Stace
# Warren Buffett
# Wau Holland
# Wesley J. Smith
# Wesley Newcomb Hohfeld
# Wilhelm Ackermann
# Wilhelm Dilthey
# Willard V. O. Quine
# Willard Van Orman Quine
# William Alston
# William Alvin Howard
# William C. Dowling
# William Craig (logician)
# William Ernest Johnson
# William Fontaine
# William George Ward
# William James
# William K. Frankena
# William Lycan
# William Paley
# William Stanley Jevons
# William Sweet
# William Whewell
# William Wollaston
# William of Ockham
# William of Sherwood
# Wolfgang Smith
# Wu Enyu
# Xavier Zubiri
# Xenocrates
# Xenophanes
# Xun Kuang
# Xun Zi
# Yamaga Sokō
# Yamazaki Ansai
# Yehoshua Bar-Hillel
# Yi I
# Yiannis N. Moschovakis
# Young Hegelians
# Yuri Matiyasevich
# Yusuf Balasagun
# Yves Marie André
# Zalman Schachter-Shalomi
# Zeno of Elea
# Zhuang Zhou
# Ziauddin Sardar
# Étienne de La Boétie
# Þorsteinn Gylfason
# İoanna Kuçuradi

# %%
import pickle
import urllib
# Run through all philosophers' links
all_phil = {}
for phil in trim_phil:
    baseurl    = "https://en.wikipedia.org/w/api.php?" # ensure English wiki
    if(phil.startswith(":")):
        # Redirect to right page if no English available
        cc = re.search(r'^:([a-zA-Z]+):',phil).group(1)
        phil = re.sub(r'^:([a-zA-Z]+):','',phil)
        baseurl = "https://%s.wikipedia.org/w/api.php?" % (cc)
    
    # Create query
    print phil
    phil_q = urllib.quote(phil.replace(" ","_"))
    query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+phil_q,content,dataformat)
    print query
    f = urllib2.urlopen(query)
    phil_all_links = re.findall(r'\[\[([^\]|]+)\|?[^\]]*\]\]',f.read())
    
    # Keep only philosopher's links
    # phil_links = [val for val in phil_all_links if val in trim_phil]
    for item in phil_all_links:
        for item2 in trim_phil:
            try:
                if item.encode('UTF-8') == item2.encode('UTF-8'):
                    item = item2
            except UnicodeDecodeError:
                print item, type(item)
                print item2, type(item2)
                
    
    # Save Philosopher's links
    all_phil[phil] = phil_links
    
phil_out = open('philosophers_associativity_list.pkl','wb')
pickle.dump(all_phil, phil_out, pickle.HIGHEST_PROTOCOL)
# Out:
# Martinus Dorpius
# https://nl.wikipedia.org/w/api.php?action=query&titles=Martinus_Dorpius&prop=revisions&rvprop=content&format=json&utf8=
# A. J. Ayer
# https://en.wikipedia.org/w/api.php?action=query&titles=A._J._Ayer&prop=revisions&rvprop=content&format=json&utf8=
# Mihailo Marković <type 'str'>
# :nl:Martinus Dorpius <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# A. J. Ayer <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Abraham Fraenkel <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Abraham Joshua Heschel <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Abraham Robinson <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Abraham ibn Daud <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Abul Kalam Azad <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Adam Müller <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Adam Smith <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Adolf Lindenbaum <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Adrian Johnston (philosopher) <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Ahmed Raza Khan <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alain Badiou <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Bundy <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Carter (philosopher) <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Gewirth <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Ross Anderson <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Ryan <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alan Turing <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alasdair MacIntyre <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alasdair Urquhart <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Alastair Norcross <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
# Albert Camus <type 'numpy.unicode_'>
# Mihailo Marković <type 'str'>
#
type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Stobaeus <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Stuart Wilde <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Sun Yat-sen <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Susan Haack <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Susan Wolf <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Susanna Schellenberg <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Susanna Siegel <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Susanne Langer <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Suzy Kassem <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Swami Vivekananda <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Søren Kierkegaard <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# T. H. Irwin <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# T. M. Scanlon <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tadeusz Czeżowski <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tadeusz Kotarbiński <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Takis Fotopoulos <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tan Sitong <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tara Smith (philosopher) <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tenzin Gyatso <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Terence McKenna <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Terence Parsons <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodor Mundt <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodor Sternberg <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodor W. Adorno <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodor Zwinger <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodore Sider <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theodore Slaman <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Theophrastus <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thiruvalluvar <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Aquinas <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Berry <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Bradwardine <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Henry Huxley <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Hill Green <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Hobbes <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Nagel <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thomas Reid <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thoralf Skolem <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Thucydides <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Théodore Simon Jouffroy <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Todd May <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Toju Nakae <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tom Beauchamp <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tom Regan <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tomek Pietkiewicz <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tony Honoré <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Trenton Merricks <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tripp York <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Tudor Vianu <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Udayana <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Umar bin al-Khattab <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Umberto Eco <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Valentin Feldman <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Vernon Lee <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Victor Basch <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Victor Cousin <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Victor Gollancz <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Virgil Aldrich <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Vissarion Belinsky <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Vladimir Andreyevich Uspensky <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Voltaire <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Voltairine de Cleyre <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# W. D. Ross <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# W. Hugh Woodin <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# W.K. Wimsatt <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# W.V.O. Quine <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Walter Benjamin <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Walter Burley <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Walter Pater <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Walter Pitts <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Walter Terence Stace <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Warren Buffett <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wau Holland <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wesley J. Smith <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wesley Newcomb Hohfeld <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wilhelm Ackermann <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wilhelm Dilthey <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Willard V. O. Quine <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Willard Van Orman Quine <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Alston <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Alvin Howard <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William C. Dowling <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Craig (logician) <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Ernest Johnson <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Fontaine <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William George Ward <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William James <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William K. Frankena <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Lycan <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Paley <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Stanley Jevons <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Sweet <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Whewell <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William Wollaston <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William of Ockham <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# William of Sherwood <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wolfgang Smith <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Wu Enyu <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Xavier Zubiri <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Xenocrates <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Xenophanes <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Xun Kuang <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Xun Zi <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yamaga Sokō <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yamazaki Ansai <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yehoshua Bar-Hillel <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yi I <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yiannis N. Moschovakis <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Young Hegelians <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yuri Matiyasevich <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yusuf Balasagun <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Yves Marie André <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Zalman Schachter-Shalomi <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Zeno of Elea <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Zhuang Zhou <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Ziauddin Sardar <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Étienne de La Boétie <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# Þorsteinn Gylfason <type 'numpy.unicode_'>
# Mustafa Kemal Atatürk <type 'str'>
# İoanna Kuçuradi <type 'numpy.unicode_'>
# Adam Müller
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-72615cf14b9f> in <module>()
#      13     # Create query
#      14     print phil
# ---> 15     phil_q = urllib.quote(phil.replace(" ","_"))
#      16     query = "%s%s&%s&%s&%s&utf8=" % (baseurl,action,title+phil_q,content,dataformat)
#      17     print query
#
# C:\Users\frksteenhoff\Anaconda2\lib\urllib.pyc in quote(s, safe)
#    1297     if not s.rstrip(safe):
#    1298         return s
# -> 1299     return ''.join(map(quoter, s))
#    1300
#    1301 def quote_plus(s, safe=''):
#
# KeyError: u'\xfc'

# %% [markdown]
# ## Other
